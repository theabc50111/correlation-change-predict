# %%
from tqdm import tqdm
from pathlib import Path
import warnings
import sys
import logging
from pprint import pformat
from itertools import product, islice
import json
from datetime import datetime

import pandas as pd
import numpy as np
import matplotlib as mpl
import torch
from torch.nn import Linear, GRU, Sequential, BatchNorm1d, ReLU, Dropout
import torch.nn.functional as F
import torch_geometric
from torch_geometric.data import Data, DataLoader
from torch_geometric.nn import GCNConv, GINConv, global_mean_pool, global_add_pool, summary
# from torchsummary import summary
import dynamic_yaml
import yaml

sys.path.append("/workspace/correlation-change-predict/ywt_library")
import data_generation
from data_generation import data_gen_cfg, gen_corr_mat_thru_t
from stl_decompn import stl_decompn
from corr_library import calc_corr_ser_property


with open('../config/data_config.yaml') as f:
    data = dynamic_yaml.load(f)
    data_cfg = yaml.full_load(dynamic_yaml.dump(data))

warnings.simplefilter("ignore")
logging.basicConfig(format='%(levelname)-8s [%(filename)s] %(message)s',
                    level=logging.INFO)
matplotlib_logger = logging.getLogger("matplotlib")
matplotlib_logger.setLevel(logging.ERROR)
mpl.rcParams[u'font.sans-serif'] = ['simhei']
mpl.rcParams['axes.unicode_minus'] = False
# logger_list = [logging.getLogger(name) for name in logging.root.manager.loggerDict]
# loggin.debug(logger_list)

# %load_ext pycodestyle_magic
# %pycodestyle_on --ignore E501
logging.debug(pformat(data_cfg, indent=1, width=100, compact=True))
logging.info(pformat(data_gen_cfg, indent=1, width=100, compact=True))
# Out:
# INFO     [2190218856.py] {'CORR_STRIDE': 1, 'CORR_WINDOW': 50, 'DATA_DIV_STRIDE': 20, 'MAX_DATA_DIV_START_ADD': 0}
# time: 1.78 s (started: 2023-02-18 16:26:23 +00:00)

# %% [markdown]
# ## Data implement & output setting & testset setting

# %%
# data implement setting
data_implement = "SP500_20082017_CORR_SER_REG_CORR_MAT_HRCHY_11_CLUSTER"  # watch options by operate: logging.info(data_cfg["DATASETS"].keys())
# train set setting
train_items_setting = "-train_train"  # -train_train|-train_all
# setting of name of output files and pictures title
output_file_name = data_cfg["DATASETS"][data_implement]['OUTPUT_FILE_NAME_BASIS'] + train_items_setting
logging.info(f"===== file_name basis:{output_file_name} =====")
# Out:
# INFO     [2257181884.py] ===== file_name basis:sp500_20082017_corr_ser_reg_corr_mat_hrchy_11_cluster-train_train =====
# time: 888 µs (started: 2023-02-18 16:26:24 +00:00)

# %%
s_l, w_l = data_gen_cfg["CORR_STRIDE"], data_gen_cfg["CORR_WINDOW"]
graph_data_dir = Path(data_cfg["DIRS"]["PIPELINE_DATA_DIR"])/f"{output_file_name}-graph_data"
model_dir = Path(f'./save_models/{output_file_name}/corr_s{s_l}_w{w_l}')
model_log_dir = Path(f'./save_models/{output_file_name}/corr_s{s_l}_w{w_l}/train_logs/')
model_dir.mkdir(parents=True, exist_ok=True)
model_log_dir.mkdir(parents=True, exist_ok=True)
# Out:
# time: 798 µs (started: 2023-02-18 16:26:24 +00:00)

# %% [markdown]
# ## model configuration

# %%
gin_enc_cfg = {"num_gin_layers": 1,  # range:1~n, for GIN after the second layer,
               "gin_dim_h": 3,
              }
data_loader_cfg = {"tr_loader_batch_size": 12,  # each graph contains 5 days correlation, so 4 graphs means a month, 12 graphs means a quarter
                   "val_loader_batch_size": 4,  # each graph contains 5 days correlation, so 4 graphs means a month, 12 graphs means a quarter
                   "test_loader_batch_size": 4,  # each graph contains 5 days correlation, so 4 graphs means a month, 12 graphs means a quarter
                  }
mts_corr_ad_cfg = {"gru_layers": 1,  # range:1~n, for gru
                   "gru_dim_out": 8,
                   }
mts_corr_ad_cfg["dim_out"] = gin_enc_cfg["num_gin_layers"] *  gin_enc_cfg["gin_dim_h"]
# Out:
# time: 597 µs (started: 2023-02-18 16:26:25 +00:00)

# %% [markdown]
# ## Load Graph Data

# %%
graph_arr = np.load(graph_data_dir/f"corr_s{s_l}_w{w_l}_graph.npy")  # each graph consist of 66 node & 66^2 edges
logging.info(f"graph_arr.shape:{graph_arr.shape}")
graph_time_step = graph_arr.shape[0] - 1  # the graph of last "t" can't be used as train data
node_attr = torch.tensor(np.zeros((graph_arr.shape[1], 1)), dtype=torch.float32)  # each node has only one attribute
edge_index = torch.tensor(list(product(range(graph_arr.shape[1]), repeat=2)))
dataset = []
for g_t in range(graph_time_step):
    edge_attr = torch.tensor(np.hstack(graph_arr[g_t]).reshape(-1, 1), dtype=torch.float32)
    edge_attr_next_t = torch.tensor(np.hstack(graph_arr[g_t+1]).reshape(-1, 1), dtype=torch.float32)
    data_y = Data(x=node_attr, edge_index=edge_index.t().contiguous(), edge_attr=edge_attr_next_t)
    data = Data(x=node_attr, y=data_y, edge_index=edge_index.t().contiguous(), edge_attr=edge_attr)
    dataset.append(data)
else:
    #mts_corr_ad_cfg["dim_out"] = data.y.shape[0]  # if the input of loss-function graphs instead of graphs' embedding
    gin_enc_cfg["num_node_features"] = data.num_node_features
    logging.info(f"data.num_node_features: {data.num_node_features}; data.num_edges: {data.num_edges}; data.num_edge_features: {data.num_edge_features}; data.is_undirected: {data.is_undirected()}; ")
    logging.info(f"data.x.shape: {data.x.shape}; data.y.x.shape: {data.y.x.shape}; data.edge_index.shape: {data.edge_index.shape}; data.edge_attr.shape: {data.edge_attr.shape}")

# Create training, validation, and test sets
train_dataset = dataset[:int(len(dataset)*0.9)]

import pickle
with open("../../tmp/tmp_torch_graph_dataset.pickle", 'wb') as handle:
    pickle.dump(train_dataset, handle, protocol=pickle.HIGHEST_PROTOCOL)
val_dataset   = dataset[int(len(dataset)*0.9):int(len(dataset)*0.95)]
test_dataset  = dataset[int(len(dataset)*0.95):]

# Create mini-batches
train_loader = DataLoader(train_dataset, batch_size = data_loader_cfg["tr_loader_batch_size"], shuffle=False)
val_loader = DataLoader(val_dataset, batch_size = data_loader_cfg["val_loader_batch_size"], shuffle=False)
test_loader = DataLoader(test_dataset, batch_size = data_loader_cfg["test_loader_batch_size"], shuffle=False)

# show info
logging.info(f'Training set   = {len(train_dataset)} graphs')
logging.info(f'Validation set = {len(val_dataset)} graphs')
logging.info(f'Test set       = {len(test_dataset)} graphs')
logging.debug('Train loader:')
for i, subgraph in enumerate(train_loader):
    logging.debug(f' - Subgraph {i}: {subgraph} ; Subgraph {i}.num_graphs:{subgraph.num_graphs}')

logging.debug('Validation loader:')
for i, subgraph in enumerate(val_loader):
    logging.debug(f' - Subgraph {i}: {subgraph} ; Subgraph{i}.num_graphs:{subgraph.num_graphs}')

logging.debug('Test loader:')
for i, subgraph in enumerate(test_loader):
    logging.debug(f' - Subgraph {i}: {subgraph} ; Subgraph{i}.num_graphs:{subgraph.num_graphs}')

logging.debug('Peeking Train data:')
data_x_nodes = next(iter(train_loader)).x.reshape(train_loader.batch_size, -1)
data_x_edges = next(iter(train_loader)).edge_attr.reshape(train_loader.batch_size, -1)
data_y_nodes = torch.cat([y.x for y in next(iter(train_loader)).y]).reshape(train_loader.batch_size, -1)
data_y_edges = torch.cat([y.edge_attr for y in next(iter(train_loader)).y]).reshape(train_loader.batch_size, -1)
for i in range(12):
    logging.debug(f"\n batch0_x{i}.shape: {data_x_nodes[i].shape} \n batch0_x{i}[:5]:{data_x_nodes[i][:5]}")
    logging.debug(f"\n batch0_x{i}_edges.shape: {data_x_edges[i].shape} \n batch0_x{i}_edges[:5]:{data_x_edges[i][:5]}")
    logging.debug(f"\n batch0_y{i}.shape: {data_y_nodes[i].shape} \n batch0_y{i}[:5]:{data_y_nodes[i][:5]}")
    logging.debug(f"\n batch0_y{i}_edges.shape: {data_y_edges[i].shape} \n batch0_y{i}_edges[:5]:{data_y_edges[i][:5]}")
# Out:
# INFO     [1425911519.py] graph_arr.shape:(2417, 66, 66)
# INFO     [1425911519.py] data.num_node_features: 1; data.num_edges: 4356; data.num_edge_features: 1; data.is_undirected: True;
# INFO     [1425911519.py] data.x.shape: torch.Size([66, 1]); data.y.x.shape: torch.Size([66, 1]); data.edge_index.shape: torch.Size([2, 4356]); data.edge_attr.shape: torch.Size([4356, 1])
# INFO     [1425911519.py] Training set   = 2174 graphs
# INFO     [1425911519.py] Validation set = 121 graphs
# INFO     [1425911519.py] Test set       = 121 graphs
# time: 1.55 s (started: 2023-02-18 16:26:25 +00:00)

# %% [markdown]
# ## Multi-Dimension Time-Series Correlation Anomly Detection Model

# %%
class MTSCorrAD(torch.nn.Module):
    """
    num_node_features: number of features per node in the graph, in this model every node has same size of features 
    gin_dim_h: output size of hidden layer of GINconv
    gru_layers: Number of recurrent layers of GRU
    gru_dim_out: The number of output size of GRU and features in the hidden state h of GRU
    dim_out: The number of output size of MTSCorrAD model
    """
    def __init__(self, num_node_features:int, num_gin_layers:int, gin_dim_h:int, gru_layers:int, gru_dim_out:int, dim_out:int, **kwargs):
        super(MTSCorrAD, self).__init__()
        self.num_gin_layers = num_gin_layers
        self.gin_convs = torch.nn.ModuleList()
        self.gin_dim_h = gin_dim_h
        gru_input_size = self.num_gin_layers * self.gin_dim_h  # the input size of GRU depend on the number of layers of GINconv
        self.gru1 = GRU(gru_input_size, gru_dim_out, gru_layers)
        self.lin1 = Linear(gru_dim_out, dim_out)
        for i in range(num_gin_layers):
            if i:
                nn = Sequential(Linear(gin_dim_h, gin_dim_h),
                                BatchNorm1d(gin_dim_h), ReLU(),
                                Linear(gin_dim_h, gin_dim_h), ReLU())
            else:
                nn = Sequential(Linear(num_node_features, gin_dim_h),
                                BatchNorm1d(gin_dim_h), ReLU(),
                                Linear(gin_dim_h, gin_dim_h), ReLU())
            self.gin_convs.append(GINConv(nn))


    def forward(self, x, edge_index, batch_node_id):
        # Inter-series modeling
        # Node embeddings
        nodes_emb_layers = []
        for i in range(self.num_gin_layers):
            if i:
                nodes_emb = self.gin_convs[i](nodes_emb, edge_index)
            else:
                nodes_emb = self.gin_convs[i](x, edge_index)  # the shape of nodes_embeds: [batch_size*num_nodes, gin_dim_h] 
            nodes_emb_layers.append(nodes_emb)

        # Graph-level readout
        nodes_emb_pools = [global_add_pool(nodes_emb, batch_node_id) for nodes_emb in nodes_emb_layers]  # the shape of global_add_pool(nodes_emb, batch_node_id): [batch_size, gin_dim_h]
                                                                                                         # global_add_pool : make a super-node to represent the graph
        # Concatenate and form the graph embeddings
        graph_embeds = torch.cat(nodes_emb_pools, dim=1)  # the shape of graph_embeds: [batch_size, num_layers*gin_dim_h]

        # Temporal Modeling
        gru_output, gru_hn = self.gru1(graph_embeds)  # regarding batch_size as time-steps(sequence length) by using "unbatched" input
        graph_embed_pred = self.lin1(gru_output[-1])  # gru_output[-1] => only take last time-step

        return graph_embed_pred


    def get_embeddings(self, x, edge_index, batch_node_id):
        with torch.no_grad():
            nodes_emb_layers = []
            for i in range(self.num_gin_layers):
                if i:
                    nodes_emb = self.gin_convs[i](nodes_emb, edge_index)
                else:
                    nodes_emb = self.gin_convs[i](x, edge_index)  # the shape of nodes_embeds: [batch_size*num_nodes, gin_dim_h] 
                nodes_emb_layers.append(nodes_emb)

            # Graph-level readout
            nodes_emb_pools = [global_add_pool(nodes_emb, batch_node_id) for nodes_emb in nodes_emb_layers]  # the shape of global_add_pool(nodes_emb, batch_node_id): [batch_size, gin_dim_h]
                                                                                                             # global_add_pool : make a super-node to represent the graph
            # Concatenate and form the graph embeddings
            graph_embeds = torch.cat(nodes_emb_pools, dim=1)  # the shape of graph_embeds: [batch_size, num_layers*gin_dim_h]

        return graph_embeds
# Out:
# time: 1.84 ms (started: 2023-02-18 16:26:26 +00:00)

# %%
def train(model:torch.nn.Module, train_loader:torch_geometric.loader.dataloader.DataLoader,
          val_loader:torch_geometric.loader.dataloader.DataLoader, optimizer, criterion, epochs:int =5, show_model_info=False):
    best_model_info = {"epochs": epochs,
                       "train_batch": train_loader.batch_size,
                       "val_batch": val_loader.batch_size,
                       "optimizer": optimizer.__str__(),
                       "criterion": criterion.__str__(),
                       "min_val_loss": float('inf'),
                       "train_loss_history": [],
                       "val_loss_history": []
                      }
    for epoch_i in tqdm(range(epochs)):
        model.train()
        train_loss = 0

        # Train on batches
        for batch_i, data in enumerate(train_loader):
            data.to("cuda")
            x, x_edge_index, x_batch_node_id, x_edge_attr = data.x, data.edge_index, data.batch, data.edge_attr
            y, y_edge_index, y_batch_node_id, y_edge_attr = data.y[-1].x, data.y[-1].edge_index, torch.zeros(data.y[-1].x.shape[0], dtype=torch.int64).to("cuda"), data.y[-1].edge_attr  # only take y of x with last time-step on training
            optimizer.zero_grad()
            graph_embeds_pred = model(x, x_edge_index, x_batch_node_id)
            y_graph_embeds = model.get_embeddings(y, y_edge_index, y_batch_node_id)
            loss =  criterion(graph_embeds_pred, y_graph_embeds)
            train_loss += loss / len(train_loader)
            # train_loss += loss
            loss.backward()
            optimizer.step()
            # if batch_i == 0:
            #     # print(sum(1 for _ in model.parameters()))
            #     # for param in model.parameters():
            #         # print(param.shape)
            #     print(f"Train in epoch_{epoch_i}_batch0, gru param:{next(islice(model.parameters(), 1, 22))}")
            #     print(f"Train in epoch_{epoch_i}_batch0, gin param:{next(islice(model.parameters(), 23, 24))}")

            if epoch_i==0 and batch_i==0:
                best_model_info["model_structure"] = model.__str__() + "\n" + "="*100 + "\n" + summary(model, data.x, data.edge_index, data.batch, max_depth=20).__str__()
                if show_model_info:
                    logging.info(f"\n{best_model_info['model_structure']}")

        # Validation
        val_loss = test(model, val_loader, criterion)

        # save best model
        if val_loss<best_model_info["min_val_loss"]:
            best_model = model
            best_model_info["best_val_epoch"] = epoch_i
            best_model_info["min_val_loss"] = val_loss.item()

        best_model_info["train_loss_history"].append(train_loss.item())
        best_model_info["val_loss_history"].append(val_loss.item())

        # show metrics every 10 epochs
        if(epoch_i % 10 == 0):
            logging.info(f"Epoch {epoch_i:>3} | Train Loss: {train_loss:.5f} | Val Loss: {val_loss:.5f} ")

    return best_model, best_model_info


def test(model:torch.nn.Module, loader:torch_geometric.loader.dataloader.DataLoader, criterion):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for batch_i, data in enumerate(loader):
            data.to("cuda")
            x, x_edge_index, x_batch_node_id, x_edge_attr = data.x, data.edge_index, data.batch, data.edge_attr
            y, y_edge_index, y_batch_node_id, y_edge_attr = data.y[-1].x, data.y[-1].edge_index, torch.zeros(data.y[-1].x.shape[0], dtype=torch.int64).to("cuda"), data.y[-1].edge_attr  # only take y of x with last time-step on training
            graph_embeds_pred = model(x, x_edge_index, x_batch_node_id)
            y_graph_embeds = model.get_embeddings(y, y_edge_index, y_batch_node_id)
            loss = criterion(graph_embeds_pred, y_graph_embeds)
            test_loss += loss / len(loader)
            # test_loss += loss
            # if batch_i == 0:
            #     print(f"Val in batch0, gru_param:{next(islice(model.parameters(), 1, 2))}")
            #     print(f"Val in batch0, gin_param:{next(islice(model.parameters(), 23, 24))}")

    return test_loss

def save_model(model:torch.nn.Module, model_info:dict, data_gen_cfg:dict):
    e_i = model_info["best_val_epoch"]
    t = datetime.strftime(datetime.now(),"%Y%m%d%H%M%S")
    torch.save(model, model_dir/f"epoch_{e_i}-{t}.pt")
    with open(model_log_dir/f"epoch_{e_i}-{t}.json","w") as f:
        json_str = json.dumps(model_info)
        f.write(json_str)
    logging.info(f"model has been saved in:{model_dir}")

mts_corr_ad_cfg = mts_corr_ad_cfg | gin_enc_cfg
model =  MTSCorrAD(**mts_corr_ad_cfg).to("cuda")
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters())
model, model_info = train(model, train_loader, val_loader, optimizer, criterion, epochs=5000, show_model_info=True)
save_model(model, model_info, data_gen_cfg)
# Out:
#   0% 0/5000 [00:00<?, ?it/s]INFO     [2557662568.py]
# MTSCorrAD(
#   (gin_convs): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=3, bias=True)
#       (1): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=3, out_features=3, bias=True)
#       (4): ReLU()
#     ))
#   )
#   (gru1): GRU(3, 8)
#   (lin1): Linear(in_features=8, out_features=3, bias=True)
# )
# ====================================================================================================
# +-------------------------+-----------------------------+-----------------+----------+
# | Layer                   | Input Shape                 | Output Shape    |   #Param |
# |-------------------------+-----------------------------+-----------------+----------|
# | MTSCorrAD               | [792, 1], [2, 52272], [792] | [3]             |      363 |
# | ├─(gin_convs)ModuleList | --                          | --              |       24 |
# | │    └─(0)GINConv       | [792, 1], [2, 52272]        | [792, 3]        |       24 |
# | ├─(gru1)GRU             | [12, 3]                     | [12, 8], [1, 8] |      312 |
# | ├─(lin1)Linear          | [8]                         | [3]             |       27 |
# +-------------------------+-----------------------------+-----------------+----------+
# INFO     [2557662568.py] Epoch   0 | Train Loss: 372.64575 | Val Loss: 330.01328
#   0% 10/5000 [00:07<59:24,  1.40it/s] INFO     [2557662568.py] Epoch  10 | Train Loss: 70.67327 | Val Loss: 63.58553
#   0% 20/5000 [00:14<57:46,  1.44it/s]INFO     [2557662568.py] Epoch  20 | Train Loss: 4.27910 | Val Loss: 3.50281
#   1% 30/5000 [00:21<58:00,  1.43it/s]INFO     [2557662568.py] Epoch  30 | Train Loss: 0.01050 | Val Loss: 0.01173
#   1% 40/5000 [00:28<57:18,  1.44it/s]INFO     [2557662568.py] Epoch  40 | Train Loss: 0.00000 | Val Loss: 0.00410
#   1% 50/5000 [00:35<56:49,  1.45it/s]INFO     [2557662568.py] Epoch  50 | Train Loss: 0.00000 | Val Loss: 0.00405
#   1% 60/5000 [00:42<57:32,  1.43it/s]INFO     [2557662568.py] Epoch  60 | Train Loss: 0.00000 | Val Loss: 0.00394
#   1% 70/5000 [00:49<57:38,  1.43it/s]INFO     [2557662568.py] Epoch  70 | Train Loss: 0.00000 | Val Loss: 0.00370
#   2% 80/5000 [00:56<57:13,  1.43it/s]INFO     [2557662568.py] Epoch  80 | Train Loss: 0.00000 | Val Loss: 0.00325
#   2% 90/5000 [01:03<57:00,  1.44it/s]INFO     [2557662568.py] Epoch  90 | Train Loss: 0.00000 | Val Loss: 0.00260
#   2% 100/5000 [01:10<57:06,  1.43it/s]INFO     [2557662568.py] Epoch 100 | Train Loss: 0.00000 | Val Loss: 0.00190
#   2% 110/5000 [01:17<57:11,  1.43it/s]INFO     [2557662568.py] Epoch 110 | Train Loss: 0.00000 | Val Loss: 0.00131
#   2% 120/5000 [01:24<56:40,  1.44it/s]INFO     [2557662568.py] Epoch 120 | Train Loss: 0.00000 | Val Loss: 0.00087
#   3% 130/5000 [01:31<57:00,  1.42it/s]INFO     [2557662568.py] Epoch 130 | Train Loss: 0.00000 | Val Loss: 0.00057
#   3% 140/5000 [01:37<55:38,  1.46it/s]INFO     [2557662568.py] Epoch 140 | Train Loss: 0.00000 | Val Loss: 0.00037
#   3% 150/5000 [01:44<56:12,  1.44it/s]INFO     [2557662568.py] Epoch 150 | Train Loss: 0.00000 | Val Loss: 0.00024
#   3% 160/5000 [01:51<56:11,  1.44it/s]INFO     [2557662568.py] Epoch 160 | Train Loss: 0.00000 | Val Loss: 0.00016
#   3% 170/5000 [01:58<56:17,  1.43it/s]INFO     [2557662568.py] Epoch 170 | Train Loss: 0.00000 | Val Loss: 0.00010
#   4% 180/5000 [02:05<56:05,  1.43it/s]INFO     [2557662568.py] Epoch 180 | Train Loss: 0.00000 | Val Loss: 0.00007
#   4% 190/5000 [02:12<56:23,  1.42it/s]INFO     [2557662568.py] Epoch 190 | Train Loss: 0.00000 | Val Loss: 0.00005
#   4% 200/5000 [02:19<56:04,  1.43it/s]INFO     [2557662568.py] Epoch 200 | Train Loss: 0.00000 | Val Loss: 0.00003
#   4% 210/5000 [02:26<56:21,  1.42it/s]INFO     [2557662568.py] Epoch 210 | Train Loss: 0.00000 | Val Loss: 0.00002
#   4% 220/5000 [02:33<56:07,  1.42it/s]INFO     [2557662568.py] Epoch 220 | Train Loss: 0.00000 | Val Loss: 0.00004
#   5% 230/5000 [02:40<55:03,  1.44it/s]INFO     [2557662568.py] Epoch 230 | Train Loss: 0.00000 | Val Loss: 0.00001
#   5% 240/5000 [02:47<55:08,  1.44it/s]INFO     [2557662568.py] Epoch 240 | Train Loss: 0.00000 | Val Loss: 0.00001
#   5% 250/5000 [02:54<55:08,  1.44it/s]INFO     [2557662568.py] Epoch 250 | Train Loss: 0.00000 | Val Loss: 0.00002
#   5% 260/5000 [03:01<55:12,  1.43it/s]INFO     [2557662568.py] Epoch 260 | Train Loss: 0.00000 | Val Loss: 0.00001
#   5% 270/5000 [03:08<48:45,  1.62it/s]INFO     [2557662568.py] Epoch 270 | Train Loss: 0.00000 | Val Loss: 0.00001
#   6% 280/5000 [03:14<48:14,  1.63it/s]INFO     [2557662568.py] Epoch 280 | Train Loss: 0.00000 | Val Loss: 0.00027
#   6% 290/5000 [03:20<48:07,  1.63it/s]INFO     [2557662568.py] Epoch 290 | Train Loss: 0.00000 | Val Loss: 0.00001
#   6% 300/5000 [03:26<48:00,  1.63it/s]INFO     [2557662568.py] Epoch 300 | Train Loss: 0.00000 | Val Loss: 0.00001
#   6% 310/5000 [03:32<47:53,  1.63it/s]INFO     [2557662568.py] Epoch 310 | Train Loss: 0.00000 | Val Loss: 0.00001
#   6% 320/5000 [03:38<47:48,  1.63it/s]INFO     [2557662568.py] Epoch 320 | Train Loss: 0.00000 | Val Loss: 0.00001
#   7% 330/5000 [03:45<52:06,  1.49it/s]INFO     [2557662568.py] Epoch 330 | Train Loss: 0.00000 | Val Loss: 0.00003
#   7% 340/5000 [03:52<54:40,  1.42it/s]INFO     [2557662568.py] Epoch 340 | Train Loss: 0.00000 | Val Loss: 0.00001
#   7% 350/5000 [03:59<54:27,  1.42it/s]INFO     [2557662568.py] Epoch 350 | Train Loss: 0.00000 | Val Loss: 0.00007
#   7% 360/5000 [04:06<54:14,  1.43it/s]INFO     [2557662568.py] Epoch 360 | Train Loss: 0.00000 | Val Loss: 0.00001
#   7% 370/5000 [04:13<54:10,  1.42it/s]INFO     [2557662568.py] Epoch 370 | Train Loss: 0.00000 | Val Loss: 0.00001
#   8% 380/5000 [04:20<54:10,  1.42it/s]INFO     [2557662568.py] Epoch 380 | Train Loss: 0.00000 | Val Loss: 0.00001
#   8% 390/5000 [04:27<53:49,  1.43it/s]INFO     [2557662568.py] Epoch 390 | Train Loss: 0.00000 | Val Loss: 0.00001
#   8% 400/5000 [04:34<53:57,  1.42it/s]INFO     [2557662568.py] Epoch 400 | Train Loss: 0.00000 | Val Loss: 0.00001
#   8% 410/5000 [04:41<53:38,  1.43it/s]INFO     [2557662568.py] Epoch 410 | Train Loss: 0.00000 | Val Loss: 0.00001
#   8% 420/5000 [04:48<53:35,  1.42it/s]INFO     [2557662568.py] Epoch 420 | Train Loss: 0.00000 | Val Loss: 0.00001
#   9% 430/5000 [04:55<53:32,  1.42it/s]INFO     [2557662568.py] Epoch 430 | Train Loss: 0.00000 | Val Loss: 0.00001
#   9% 440/5000 [05:02<53:26,  1.42it/s]INFO     [2557662568.py] Epoch 440 | Train Loss: 0.00000 | Val Loss: 0.00000
#   9% 450/5000 [05:09<53:20,  1.42it/s]INFO     [2557662568.py] Epoch 450 | Train Loss: 0.00000 | Val Loss: 0.00001
#   9% 460/5000 [05:16<52:48,  1.43it/s]INFO     [2557662568.py] Epoch 460 | Train Loss: 0.00000 | Val Loss: 0.00001
#   9% 470/5000 [05:23<52:46,  1.43it/s]INFO     [2557662568.py] Epoch 470 | Train Loss: 0.00000 | Val Loss: 0.00001
#  10% 480/5000 [05:30<53:09,  1.42it/s]INFO     [2557662568.py] Epoch 480 | Train Loss: 0.00000 | Val Loss: 0.00001
#  10% 490/5000 [05:37<52:36,  1.43it/s]INFO     [2557662568.py] Epoch 490 | Train Loss: 0.00000 | Val Loss: 0.00001
#  10% 500/5000 [05:44<52:17,  1.43it/s]INFO     [2557662568.py] Epoch 500 | Train Loss: 0.00000 | Val Loss: 0.00001
#  10% 510/5000 [05:51<52:10,  1.43it/s]INFO     [2557662568.py] Epoch 510 | Train Loss: 0.00000 | Val Loss: 0.00001
#  10% 520/5000 [05:58<52:03,  1.43it/s]INFO     [2557662568.py] Epoch 520 | Train Loss: 0.00000 | Val Loss: 0.00001
#  11% 530/5000 [06:05<51:33,  1.44it/s]INFO     [2557662568.py] Epoch 530 | Train Loss: 0.00000 | Val Loss: 0.00001
#  11% 540/5000 [06:12<52:23,  1.42it/s]INFO     [2557662568.py] Epoch 540 | Train Loss: 0.00000 | Val Loss: 0.00001
#  11% 550/5000 [06:19<52:00,  1.43it/s]INFO     [2557662568.py] Epoch 550 | Train Loss: 0.00000 | Val Loss: 0.00001
#  11% 560/5000 [06:26<51:41,  1.43it/s]INFO     [2557662568.py] Epoch 560 | Train Loss: 0.00000 | Val Loss: 0.00001
#  11% 570/5000 [06:33<51:55,  1.42it/s]INFO     [2557662568.py] Epoch 570 | Train Loss: 0.00000 | Val Loss: 0.00001
#  12% 580/5000 [06:40<51:42,  1.42it/s]INFO     [2557662568.py] Epoch 580 | Train Loss: 0.00000 | Val Loss: 0.00001
#  12% 590/5000 [06:47<51:49,  1.42it/s]INFO     [2557662568.py] Epoch 590 | Train Loss: 0.00000 | Val Loss: 0.00000
#  12% 600/5000 [06:54<51:33,  1.42it/s]INFO     [2557662568.py] Epoch 600 | Train Loss: 0.00000 | Val Loss: 0.00004
#  12% 610/5000 [07:01<51:04,  1.43it/s]INFO     [2557662568.py] Epoch 610 | Train Loss: 0.00000 | Val Loss: 0.00001
#  12% 620/5000 [07:08<50:19,  1.45it/s]INFO     [2557662568.py] Epoch 620 | Train Loss: 0.00000 | Val Loss: 0.00001
#  13% 630/5000 [07:15<50:36,  1.44it/s]INFO     [2557662568.py] Epoch 630 | Train Loss: 0.00000 | Val Loss: 0.00001
#  13% 640/5000 [07:22<51:33,  1.41it/s]INFO     [2557662568.py] Epoch 640 | Train Loss: 0.00000 | Val Loss: 0.00001
#  13% 650/5000 [07:29<50:45,  1.43it/s]INFO     [2557662568.py] Epoch 650 | Train Loss: 0.00000 | Val Loss: 0.00001
#  13% 660/5000 [07:36<50:30,  1.43it/s]INFO     [2557662568.py] Epoch 660 | Train Loss: 0.00000 | Val Loss: 0.00001
#  13% 670/5000 [07:43<50:25,  1.43it/s]INFO     [2557662568.py] Epoch 670 | Train Loss: 0.00000 | Val Loss: 0.00003
#  14% 680/5000 [07:50<50:02,  1.44it/s]INFO     [2557662568.py] Epoch 680 | Train Loss: 0.00000 | Val Loss: 0.00000
#  14% 690/5000 [07:56<49:49,  1.44it/s]INFO     [2557662568.py] Epoch 690 | Train Loss: 0.00000 | Val Loss: 0.00001
#  14% 700/5000 [08:03<50:04,  1.43it/s]INFO     [2557662568.py] Epoch 700 | Train Loss: 0.00000 | Val Loss: 0.00001
#  14% 710/5000 [08:11<50:54,  1.40it/s]INFO     [2557662568.py] Epoch 710 | Train Loss: 0.00000 | Val Loss: 0.00001
#  14% 720/5000 [08:17<49:35,  1.44it/s]INFO     [2557662568.py] Epoch 720 | Train Loss: 0.00000 | Val Loss: 0.00001
#  15% 730/5000 [08:24<50:13,  1.42it/s]INFO     [2557662568.py] Epoch 730 | Train Loss: 0.00000 | Val Loss: 0.00001
#  15% 740/5000 [08:32<49:53,  1.42it/s]INFO     [2557662568.py] Epoch 740 | Train Loss: 0.00000 | Val Loss: 0.00001
#  15% 750/5000 [08:39<49:47,  1.42it/s]INFO     [2557662568.py] Epoch 750 | Train Loss: 0.00000 | Val Loss: 0.00001
#  15% 760/5000 [08:46<50:02,  1.41it/s]INFO     [2557662568.py] Epoch 760 | Train Loss: 0.00000 | Val Loss: 0.00000
#  15% 770/5000 [08:53<49:39,  1.42it/s]INFO     [2557662568.py] Epoch 770 | Train Loss: 0.00000 | Val Loss: 0.00001
#  16% 780/5000 [09:00<49:21,  1.42it/s]INFO     [2557662568.py] Epoch 780 | Train Loss: 0.00000 | Val Loss: 0.00001
#  16% 790/5000 [09:07<49:21,  1.42it/s]INFO     [2557662568.py] Epoch 790 | Train Loss: 0.00000 | Val Loss: 0.00000
#  16% 800/5000 [09:14<49:11,  1.42it/s]INFO     [2557662568.py] Epoch 800 | Train Loss: 0.00000 | Val Loss: 0.00000
#  16% 810/5000 [09:21<48:55,  1.43it/s]INFO     [2557662568.py] Epoch 810 | Train Loss: 0.00000 | Val Loss: 0.00001
#  16% 820/5000 [09:28<49:14,  1.41it/s]INFO     [2557662568.py] Epoch 820 | Train Loss: 0.00000 | Val Loss: 0.00000
#  17% 830/5000 [09:35<48:45,  1.43it/s]INFO     [2557662568.py] Epoch 830 | Train Loss: 0.00000 | Val Loss: 0.00000
#  17% 840/5000 [09:42<48:29,  1.43it/s]INFO     [2557662568.py] Epoch 840 | Train Loss: 0.00000 | Val Loss: 0.00001
#  17% 850/5000 [09:49<48:12,  1.43it/s]INFO     [2557662568.py] Epoch 850 | Train Loss: 0.00000 | Val Loss: 0.00000
#  17% 860/5000 [09:56<48:24,  1.43it/s]INFO     [2557662568.py] Epoch 860 | Train Loss: 0.00000 | Val Loss: 0.00000
#  17% 870/5000 [10:03<48:29,  1.42it/s]INFO     [2557662568.py] Epoch 870 | Train Loss: 0.00000 | Val Loss: 0.00001
#  18% 880/5000 [10:10<48:06,  1.43it/s]INFO     [2557662568.py] Epoch 880 | Train Loss: 0.00000 | Val Loss: 0.00000
#  18% 890/5000 [10:17<48:06,  1.42it/s]INFO     [2557662568.py] Epoch 890 | Train Loss: 0.00000 | Val Loss: 0.00001
#  18% 900/5000 [10:24<48:35,  1.41it/s]INFO     [2557662568.py] Epoch 900 | Train Loss: 0.00000 | Val Loss: 0.00000
#  18% 910/5000 [10:31<48:09,  1.42it/s]INFO     [2557662568.py] Epoch 910 | Train Loss: 0.00000 | Val Loss: 0.00001
#  18% 920/5000 [10:38<48:19,  1.41it/s]INFO     [2557662568.py] Epoch 920 | Train Loss: 0.00000 | Val Loss: 0.00000
#  19% 930/5000 [10:45<47:46,  1.42it/s]INFO     [2557662568.py] Epoch 930 | Train Loss: 0.00000 | Val Loss: 0.00000
#  19% 940/5000 [10:52<47:39,  1.42it/s]INFO     [2557662568.py] Epoch 940 | Train Loss: 0.00000 | Val Loss: 0.00000
#  19% 950/5000 [10:59<47:42,  1.41it/s]INFO     [2557662568.py] Epoch 950 | Train Loss: 0.00000 | Val Loss: 0.00000
#  19% 960/5000 [11:06<47:21,  1.42it/s]INFO     [2557662568.py] Epoch 960 | Train Loss: 0.00000 | Val Loss: 0.00000
#  19% 970/5000 [11:13<46:25,  1.45it/s]INFO     [2557662568.py] Epoch 970 | Train Loss: 0.00000 | Val Loss: 0.00000
#  20% 980/5000 [11:20<51:51,  1.29it/s]INFO     [2557662568.py] Epoch 980 | Train Loss: 0.00000 | Val Loss: 0.00001
#  20% 990/5000 [11:29<53:55,  1.24it/s]INFO     [2557662568.py] Epoch 990 | Train Loss: 0.00000 | Val Loss: 0.00000
#  20% 1000/5000 [11:36<48:50,  1.37it/s]INFO     [2557662568.py] Epoch 1000 | Train Loss: 0.00000 | Val Loss: 0.00000
#  20% 1010/5000 [11:44<53:41,  1.24it/s]INFO     [2557662568.py] Epoch 1010 | Train Loss: 0.00000 | Val Loss: 0.00000
#  20% 1020/5000 [11:52<49:38,  1.34it/s]INFO     [2557662568.py] Epoch 1020 | Train Loss: 0.00000 | Val Loss: 0.00000
#  21% 1030/5000 [11:59<46:22,  1.43it/s]INFO     [2557662568.py] Epoch 1030 | Train Loss: 0.00000 | Val Loss: 0.00000
#  21% 1040/5000 [12:06<46:03,  1.43it/s]INFO     [2557662568.py] Epoch 1040 | Train Loss: 0.00000 | Val Loss: 0.00000
#  21% 1050/5000 [12:13<45:41,  1.44it/s]INFO     [2557662568.py] Epoch 1050 | Train Loss: 0.00000 | Val Loss: 0.00000
#  21% 1060/5000 [12:20<46:08,  1.42it/s]INFO     [2557662568.py] Epoch 1060 | Train Loss: 0.00000 | Val Loss: 0.00000
#  21% 1070/5000 [12:27<45:57,  1.42it/s]INFO     [2557662568.py] Epoch 1070 | Train Loss: 0.00000 | Val Loss: 0.00000
#  22% 1080/5000 [12:34<45:31,  1.43it/s]INFO     [2557662568.py] Epoch 1080 | Train Loss: 0.00000 | Val Loss: 0.00000
#  22% 1090/5000 [12:41<45:16,  1.44it/s]INFO     [2557662568.py] Epoch 1090 | Train Loss: 0.00000 | Val Loss: 0.00000
#  22% 1100/5000 [12:48<45:34,  1.43it/s]INFO     [2557662568.py] Epoch 1100 | Train Loss: 0.00000 | Val Loss: 0.00001
#  22% 1110/5000 [12:55<45:23,  1.43it/s]INFO     [2557662568.py] Epoch 1110 | Train Loss: 0.00000 | Val Loss: 0.00000
#  22% 1120/5000 [13:02<44:56,  1.44it/s]INFO     [2557662568.py] Epoch 1120 | Train Loss: 0.00000 | Val Loss: 0.00001
#  23% 1130/5000 [13:09<44:50,  1.44it/s]INFO     [2557662568.py] Epoch 1130 | Train Loss: 0.00000 | Val Loss: 0.00000
#  23% 1140/5000 [13:16<45:05,  1.43it/s]INFO     [2557662568.py] Epoch 1140 | Train Loss: 0.00000 | Val Loss: 0.00000
#  23% 1150/5000 [13:23<44:48,  1.43it/s]INFO     [2557662568.py] Epoch 1150 | Train Loss: 0.00000 | Val Loss: 0.00000
#  23% 1160/5000 [13:30<44:45,  1.43it/s]INFO     [2557662568.py] Epoch 1160 | Train Loss: 0.00000 | Val Loss: 0.00000
#  23% 1170/5000 [13:37<44:51,  1.42it/s]INFO     [2557662568.py] Epoch 1170 | Train Loss: 0.00000 | Val Loss: 0.00001
#  24% 1180/5000 [13:44<44:35,  1.43it/s]INFO     [2557662568.py] Epoch 1180 | Train Loss: 0.00000 | Val Loss: 0.00000
#  24% 1190/5000 [13:51<44:40,  1.42it/s]INFO     [2557662568.py] Epoch 1190 | Train Loss: 0.00000 | Val Loss: 0.00000
#  24% 1200/5000 [13:58<44:14,  1.43it/s]INFO     [2557662568.py] Epoch 1200 | Train Loss: 0.00000 | Val Loss: 0.00000
#  24% 1210/5000 [14:05<44:02,  1.43it/s]INFO     [2557662568.py] Epoch 1210 | Train Loss: 0.00000 | Val Loss: 0.00000
#  24% 1220/5000 [14:12<44:04,  1.43it/s]INFO     [2557662568.py] Epoch 1220 | Train Loss: 0.00000 | Val Loss: 0.00000
#  25% 1230/5000 [14:19<44:12,  1.42it/s]INFO     [2557662568.py] Epoch 1230 | Train Loss: 0.00000 | Val Loss: 0.00001
#  25% 1240/5000 [14:26<43:37,  1.44it/s]INFO     [2557662568.py] Epoch 1240 | Train Loss: 0.00000 | Val Loss: 0.00001
#  25% 1250/5000 [14:33<44:13,  1.41it/s]INFO     [2557662568.py] Epoch 1250 | Train Loss: 0.00000 | Val Loss: 0.00001
#  25% 1260/5000 [14:40<43:08,  1.44it/s]INFO     [2557662568.py] Epoch 1260 | Train Loss: 0.00000 | Val Loss: 0.00000
#  25% 1270/5000 [14:47<42:59,  1.45it/s]INFO     [2557662568.py] Epoch 1270 | Train Loss: 0.00000 | Val Loss: 0.00000
#  26% 1280/5000 [14:54<42:57,  1.44it/s]INFO     [2557662568.py] Epoch 1280 | Train Loss: 0.00000 | Val Loss: 0.00000
#  26% 1290/5000 [15:01<43:05,  1.43it/s]INFO     [2557662568.py] Epoch 1290 | Train Loss: 0.00000 | Val Loss: 0.00000
#  26% 1300/5000 [15:08<43:21,  1.42it/s]INFO     [2557662568.py] Epoch 1300 | Train Loss: 0.00000 | Val Loss: 0.00000
#  26% 1310/5000 [15:15<42:51,  1.43it/s]INFO     [2557662568.py] Epoch 1310 | Train Loss: 0.00000 | Val Loss: 0.00000
#  26% 1320/5000 [15:22<42:36,  1.44it/s]INFO     [2557662568.py] Epoch 1320 | Train Loss: 0.00000 | Val Loss: 0.00000
#  27% 1330/5000 [15:29<42:55,  1.42it/s]INFO     [2557662568.py] Epoch 1330 | Train Loss: 0.00000 | Val Loss: 0.00000
#  27% 1340/5000 [15:36<42:47,  1.43it/s]INFO     [2557662568.py] Epoch 1340 | Train Loss: 0.00000 | Val Loss: 0.00000
#  27% 1350/5000 [15:43<42:13,  1.44it/s]INFO     [2557662568.py] Epoch 1350 | Train Loss: 0.00000 | Val Loss: 0.00001
#  27% 1360/5000 [15:50<42:49,  1.42it/s]INFO     [2557662568.py] Epoch 1360 | Train Loss: 0.00000 | Val Loss: 0.00000
#  27% 1370/5000 [15:57<41:43,  1.45it/s]INFO     [2557662568.py] Epoch 1370 | Train Loss: 0.00000 | Val Loss: 0.00000
#  28% 1380/5000 [16:04<41:52,  1.44it/s]INFO     [2557662568.py] Epoch 1380 | Train Loss: 0.00000 | Val Loss: 0.00000
#  28% 1390/5000 [16:11<41:51,  1.44it/s]INFO     [2557662568.py] Epoch 1390 | Train Loss: 0.00000 | Val Loss: 0.00000
#  28% 1400/5000 [16:18<42:20,  1.42it/s]INFO     [2557662568.py] Epoch 1400 | Train Loss: 0.00000 | Val Loss: 0.00000
#  28% 1410/5000 [16:26<48:05,  1.24it/s]INFO     [2557662568.py] Epoch 1410 | Train Loss: 0.00000 | Val Loss: 0.00000
#  28% 1420/5000 [16:34<48:22,  1.23it/s]INFO     [2557662568.py] Epoch 1420 | Train Loss: 0.00000 | Val Loss: 0.00001
#  29% 1430/5000 [16:42<48:25,  1.23it/s]INFO     [2557662568.py] Epoch 1430 | Train Loss: 0.00000 | Val Loss: 0.00000
#  29% 1440/5000 [16:50<44:40,  1.33it/s]INFO     [2557662568.py] Epoch 1440 | Train Loss: 0.00000 | Val Loss: 0.00000
#  29% 1450/5000 [16:57<42:04,  1.41it/s]INFO     [2557662568.py] Epoch 1450 | Train Loss: 0.00000 | Val Loss: 0.00000
#  29% 1460/5000 [17:04<41:04,  1.44it/s]INFO     [2557662568.py] Epoch 1460 | Train Loss: 0.00000 | Val Loss: 0.00000
#  29% 1470/5000 [17:11<41:16,  1.43it/s]INFO     [2557662568.py] Epoch 1470 | Train Loss: 0.00000 | Val Loss: 0.00000
#  30% 1480/5000 [17:18<41:16,  1.42it/s]INFO     [2557662568.py] Epoch 1480 | Train Loss: 0.00000 | Val Loss: 0.00000
#  30% 1490/5000 [17:25<40:49,  1.43it/s]INFO     [2557662568.py] Epoch 1490 | Train Loss: 0.00000 | Val Loss: 0.00000
#  30% 1500/5000 [17:32<40:56,  1.42it/s]INFO     [2557662568.py] Epoch 1500 | Train Loss: 0.00000 | Val Loss: 0.00000
#  30% 1510/5000 [17:39<40:48,  1.43it/s]INFO     [2557662568.py] Epoch 1510 | Train Loss: 0.00000 | Val Loss: 0.00000
#  30% 1520/5000 [17:46<40:56,  1.42it/s]INFO     [2557662568.py] Epoch 1520 | Train Loss: 0.00000 | Val Loss: 0.00000
#  31% 1530/5000 [17:53<40:24,  1.43it/s]INFO     [2557662568.py] Epoch 1530 | Train Loss: 0.00000 | Val Loss: 0.00000
#  31% 1540/5000 [18:00<40:02,  1.44it/s]INFO     [2557662568.py] Epoch 1540 | Train Loss: 0.00000 | Val Loss: 0.00000
#  31% 1550/5000 [18:07<40:25,  1.42it/s]INFO     [2557662568.py] Epoch 1550 | Train Loss: 0.00000 | Val Loss: 0.00000
#  31% 1560/5000 [18:14<39:55,  1.44it/s]INFO     [2557662568.py] Epoch 1560 | Train Loss: 0.00000 | Val Loss: 0.00003
#  31% 1570/5000 [18:21<39:59,  1.43it/s]INFO     [2557662568.py] Epoch 1570 | Train Loss: 0.00000 | Val Loss: 0.00001
#  32% 1580/5000 [18:28<40:03,  1.42it/s]INFO     [2557662568.py] Epoch 1580 | Train Loss: 0.00000 | Val Loss: 0.00000
#  32% 1590/5000 [18:35<39:58,  1.42it/s]INFO     [2557662568.py] Epoch 1590 | Train Loss: 0.00000 | Val Loss: 0.00000
#  32% 1600/5000 [18:42<39:52,  1.42it/s]INFO     [2557662568.py] Epoch 1600 | Train Loss: 0.00000 | Val Loss: 0.00000
#  32% 1610/5000 [18:49<39:17,  1.44it/s]INFO     [2557662568.py] Epoch 1610 | Train Loss: 0.00000 | Val Loss: 0.00001
#  32% 1620/5000 [18:56<39:28,  1.43it/s]INFO     [2557662568.py] Epoch 1620 | Train Loss: 0.00000 | Val Loss: 0.00000
#  33% 1630/5000 [19:03<39:02,  1.44it/s]INFO     [2557662568.py] Epoch 1630 | Train Loss: 0.00000 | Val Loss: 0.00000
#  33% 1640/5000 [19:10<39:01,  1.43it/s]INFO     [2557662568.py] Epoch 1640 | Train Loss: 0.00000 | Val Loss: 0.00000
#  33% 1650/5000 [19:17<39:22,  1.42it/s]INFO     [2557662568.py] Epoch 1650 | Train Loss: 0.00000 | Val Loss: 0.00000
#  33% 1660/5000 [19:24<39:07,  1.42it/s]INFO     [2557662568.py] Epoch 1660 | Train Loss: 0.00000 | Val Loss: 0.00001
#  33% 1670/5000 [19:31<39:11,  1.42it/s]INFO     [2557662568.py] Epoch 1670 | Train Loss: 0.00000 | Val Loss: 0.00000
#  34% 1680/5000 [19:38<38:48,  1.43it/s]INFO     [2557662568.py] Epoch 1680 | Train Loss: 0.00000 | Val Loss: 0.00000
#  34% 1690/5000 [19:45<38:33,  1.43it/s]INFO     [2557662568.py] Epoch 1690 | Train Loss: 0.00000 | Val Loss: 0.00000
#  34% 1700/5000 [19:52<38:43,  1.42it/s]INFO     [2557662568.py] Epoch 1700 | Train Loss: 0.00000 | Val Loss: 0.00000
#  34% 1710/5000 [19:59<38:46,  1.41it/s]INFO     [2557662568.py] Epoch 1710 | Train Loss: 0.00000 | Val Loss: 0.00000
#  34% 1720/5000 [20:06<38:00,  1.44it/s]INFO     [2557662568.py] Epoch 1720 | Train Loss: 0.00000 | Val Loss: 0.00000
#  35% 1730/5000 [20:13<38:30,  1.42it/s]INFO     [2557662568.py] Epoch 1730 | Train Loss: 0.00000 | Val Loss: 0.00000
#  35% 1740/5000 [20:20<37:57,  1.43it/s]INFO     [2557662568.py] Epoch 1740 | Train Loss: 0.00000 | Val Loss: 0.00000
#  35% 1750/5000 [20:27<37:29,  1.45it/s]INFO     [2557662568.py] Epoch 1750 | Train Loss: 0.00000 | Val Loss: 0.00000
#  35% 1760/5000 [20:34<37:28,  1.44it/s]INFO     [2557662568.py] Epoch 1760 | Train Loss: 0.00000 | Val Loss: 0.00000
#  35% 1770/5000 [20:41<37:47,  1.42it/s]INFO     [2557662568.py] Epoch 1770 | Train Loss: 0.00000 | Val Loss: 0.00000
#  36% 1780/5000 [20:48<37:08,  1.44it/s]INFO     [2557662568.py] Epoch 1780 | Train Loss: 0.00000 | Val Loss: 0.00000
#  36% 1790/5000 [20:55<37:14,  1.44it/s]INFO     [2557662568.py] Epoch 1790 | Train Loss: 0.00000 | Val Loss: 0.00000
#  36% 1800/5000 [21:02<37:19,  1.43it/s]INFO     [2557662568.py] Epoch 1800 | Train Loss: 0.00000 | Val Loss: 0.00000
#  36% 1810/5000 [21:09<36:57,  1.44it/s]INFO     [2557662568.py] Epoch 1810 | Train Loss: 0.00000 | Val Loss: 0.00000
#  36% 1820/5000 [21:16<37:00,  1.43it/s]INFO     [2557662568.py] Epoch 1820 | Train Loss: 0.00000 | Val Loss: 0.00000
#  37% 1830/5000 [21:23<37:10,  1.42it/s]INFO     [2557662568.py] Epoch 1830 | Train Loss: 0.00000 | Val Loss: 0.00000
#  37% 1840/5000 [21:30<37:03,  1.42it/s]INFO     [2557662568.py] Epoch 1840 | Train Loss: 0.00000 | Val Loss: 0.00000
#  37% 1850/5000 [21:37<36:45,  1.43it/s]INFO     [2557662568.py] Epoch 1850 | Train Loss: 0.00000 | Val Loss: 0.00000
#  37% 1860/5000 [21:44<36:33,  1.43it/s]INFO     [2557662568.py] Epoch 1860 | Train Loss: 0.00000 | Val Loss: 0.00000
#  37% 1870/5000 [21:51<36:19,  1.44it/s]INFO     [2557662568.py] Epoch 1870 | Train Loss: 0.00000 | Val Loss: 0.00000
#  38% 1880/5000 [21:58<36:19,  1.43it/s]INFO     [2557662568.py] Epoch 1880 | Train Loss: 0.00000 | Val Loss: 0.00000
#  38% 1890/5000 [22:05<36:23,  1.42it/s]INFO     [2557662568.py] Epoch 1890 | Train Loss: 0.00000 | Val Loss: 0.00000
#  38% 1900/5000 [22:12<36:31,  1.41it/s]INFO     [2557662568.py] Epoch 1900 | Train Loss: 0.00000 | Val Loss: 0.00000
#  38% 1910/5000 [22:19<36:17,  1.42it/s]INFO     [2557662568.py] Epoch 1910 | Train Loss: 0.00000 | Val Loss: 0.00000
#  38% 1920/5000 [22:26<36:26,  1.41it/s]INFO     [2557662568.py] Epoch 1920 | Train Loss: 0.00000 | Val Loss: 0.00001
#  39% 1930/5000 [22:33<35:57,  1.42it/s]INFO     [2557662568.py] Epoch 1930 | Train Loss: 0.00000 | Val Loss: 0.00000
#  39% 1940/5000 [22:40<35:58,  1.42it/s]INFO     [2557662568.py] Epoch 1940 | Train Loss: 0.00000 | Val Loss: 0.00000
#  39% 1950/5000 [22:47<35:33,  1.43it/s]INFO     [2557662568.py] Epoch 1950 | Train Loss: 0.00000 | Val Loss: 0.00002
#  39% 1960/5000 [22:54<35:26,  1.43it/s]INFO     [2557662568.py] Epoch 1960 | Train Loss: 0.00000 | Val Loss: 0.00000
#  39% 1970/5000 [23:01<35:11,  1.43it/s]INFO     [2557662568.py] Epoch 1970 | Train Loss: 0.00000 | Val Loss: 0.00000
#  40% 1980/5000 [23:08<35:16,  1.43it/s]INFO     [2557662568.py] Epoch 1980 | Train Loss: 0.00000 | Val Loss: 0.00000
#  40% 1990/5000 [23:15<31:16,  1.60it/s]INFO     [2557662568.py] Epoch 1990 | Train Loss: 0.00000 | Val Loss: 0.00002
#  40% 2000/5000 [23:22<35:01,  1.43it/s]INFO     [2557662568.py] Epoch 2000 | Train Loss: 0.00000 | Val Loss: 0.00000
#  40% 2010/5000 [23:29<34:53,  1.43it/s]INFO     [2557662568.py] Epoch 2010 | Train Loss: 0.00000 | Val Loss: 0.00000
#  40% 2020/5000 [23:36<35:00,  1.42it/s]INFO     [2557662568.py] Epoch 2020 | Train Loss: 0.00000 | Val Loss: 0.00000
#  41% 2030/5000 [23:43<38:59,  1.27it/s]INFO     [2557662568.py] Epoch 2030 | Train Loss: 0.00000 | Val Loss: 0.00000
#  41% 2040/5000 [23:51<39:49,  1.24it/s]INFO     [2557662568.py] Epoch 2040 | Train Loss: 0.00000 | Val Loss: 0.00000
#  41% 2050/5000 [23:59<39:40,  1.24it/s]INFO     [2557662568.py] Epoch 2050 | Train Loss: 0.00000 | Val Loss: 0.00000
#  41% 2060/5000 [24:07<39:21,  1.24it/s]INFO     [2557662568.py] Epoch 2060 | Train Loss: 0.00000 | Val Loss: 0.00000
#  41% 2070/5000 [24:14<34:24,  1.42it/s]INFO     [2557662568.py] Epoch 2070 | Train Loss: 0.00000 | Val Loss: 0.00000
#  42% 2080/5000 [24:21<34:00,  1.43it/s]INFO     [2557662568.py] Epoch 2080 | Train Loss: 0.00000 | Val Loss: 0.00000
#  42% 2090/5000 [24:28<34:14,  1.42it/s]INFO     [2557662568.py] Epoch 2090 | Train Loss: 0.00000 | Val Loss: 0.00000
#  42% 2100/5000 [24:35<33:52,  1.43it/s]INFO     [2557662568.py] Epoch 2100 | Train Loss: 0.00000 | Val Loss: 0.00000
#  42% 2110/5000 [24:42<32:53,  1.46it/s]INFO     [2557662568.py] Epoch 2110 | Train Loss: 0.00000 | Val Loss: 0.00001
#  42% 2120/5000 [24:49<33:37,  1.43it/s]INFO     [2557662568.py] Epoch 2120 | Train Loss: 0.00000 | Val Loss: 0.00000
#  43% 2130/5000 [24:56<33:23,  1.43it/s]INFO     [2557662568.py] Epoch 2130 | Train Loss: 0.00000 | Val Loss: 0.00001
#  43% 2140/5000 [25:03<33:01,  1.44it/s]INFO     [2557662568.py] Epoch 2140 | Train Loss: 0.00000 | Val Loss: 0.00002
#  43% 2150/5000 [25:11<37:51,  1.25it/s]INFO     [2557662568.py] Epoch 2150 | Train Loss: 0.00000 | Val Loss: 0.00000
#  43% 2160/5000 [25:19<38:05,  1.24it/s]INFO     [2557662568.py] Epoch 2160 | Train Loss: 0.00000 | Val Loss: 0.00000
#  43% 2170/5000 [25:27<37:57,  1.24it/s]INFO     [2557662568.py] Epoch 2170 | Train Loss: 0.00000 | Val Loss: 0.00001
#  44% 2180/5000 [25:35<34:08,  1.38it/s]INFO     [2557662568.py] Epoch 2180 | Train Loss: 0.00000 | Val Loss: 0.00000
#  44% 2190/5000 [25:42<32:37,  1.44it/s]INFO     [2557662568.py] Epoch 2190 | Train Loss: 0.00000 | Val Loss: 0.00002
#  44% 2200/5000 [25:49<32:47,  1.42it/s]INFO     [2557662568.py] Epoch 2200 | Train Loss: 0.00000 | Val Loss: 0.00000
#  44% 2210/5000 [25:56<32:17,  1.44it/s]INFO     [2557662568.py] Epoch 2210 | Train Loss: 0.00000 | Val Loss: 0.00000
#  44% 2220/5000 [26:03<32:37,  1.42it/s]INFO     [2557662568.py] Epoch 2220 | Train Loss: 0.00000 | Val Loss: 0.00000
#  45% 2230/5000 [26:10<32:27,  1.42it/s]INFO     [2557662568.py] Epoch 2230 | Train Loss: 0.00000 | Val Loss: 0.00000
#  45% 2240/5000 [26:17<32:01,  1.44it/s]INFO     [2557662568.py] Epoch 2240 | Train Loss: 0.00000 | Val Loss: 0.00000
#  45% 2250/5000 [26:24<32:09,  1.42it/s]INFO     [2557662568.py] Epoch 2250 | Train Loss: 0.00000 | Val Loss: 0.00001
#  45% 2260/5000 [26:31<32:07,  1.42it/s]INFO     [2557662568.py] Epoch 2260 | Train Loss: 0.00000 | Val Loss: 0.00001
#  45% 2270/5000 [26:38<31:58,  1.42it/s]INFO     [2557662568.py] Epoch 2270 | Train Loss: 0.00000 | Val Loss: 0.00001
#  46% 2280/5000 [26:45<31:16,  1.45it/s]INFO     [2557662568.py] Epoch 2280 | Train Loss: 0.00000 | Val Loss: 0.00000
#  46% 2290/5000 [26:52<31:40,  1.43it/s]INFO     [2557662568.py] Epoch 2290 | Train Loss: 0.00000 | Val Loss: 0.00001
#  46% 2300/5000 [26:59<31:24,  1.43it/s]INFO     [2557662568.py] Epoch 2300 | Train Loss: 0.00000 | Val Loss: 0.00001
#  46% 2310/5000 [27:06<31:27,  1.43it/s]INFO     [2557662568.py] Epoch 2310 | Train Loss: 0.00000 | Val Loss: 0.00001
#  46% 2320/5000 [27:13<30:50,  1.45it/s]INFO     [2557662568.py] Epoch 2320 | Train Loss: 0.00000 | Val Loss: 0.00001
#  47% 2330/5000 [27:20<30:59,  1.44it/s]INFO     [2557662568.py] Epoch 2330 | Train Loss: 0.00000 | Val Loss: 0.00001
#  47% 2340/5000 [27:27<34:20,  1.29it/s]INFO     [2557662568.py] Epoch 2340 | Train Loss: 0.00000 | Val Loss: 0.00001
#  47% 2350/5000 [27:35<31:52,  1.39it/s]INFO     [2557662568.py] Epoch 2350 | Train Loss: 0.00000 | Val Loss: 0.00001
#  47% 2360/5000 [27:42<32:20,  1.36it/s]INFO     [2557662568.py] Epoch 2360 | Train Loss: 0.00000 | Val Loss: 0.00001
#  47% 2370/5000 [27:50<35:08,  1.25it/s]INFO     [2557662568.py] Epoch 2370 | Train Loss: 0.00000 | Val Loss: 0.00001
#  48% 2380/5000 [27:58<35:07,  1.24it/s]INFO     [2557662568.py] Epoch 2380 | Train Loss: 0.00000 | Val Loss: 0.00001
#  48% 2390/5000 [28:06<35:09,  1.24it/s]INFO     [2557662568.py] Epoch 2390 | Train Loss: 0.00000 | Val Loss: 0.00001
#  48% 2400/5000 [28:14<32:06,  1.35it/s]INFO     [2557662568.py] Epoch 2400 | Train Loss: 0.00000 | Val Loss: 0.00001
#  48% 2410/5000 [28:21<30:24,  1.42it/s]INFO     [2557662568.py] Epoch 2410 | Train Loss: 0.00000 | Val Loss: 0.00001
#  48% 2420/5000 [28:28<30:05,  1.43it/s]INFO     [2557662568.py] Epoch 2420 | Train Loss: 0.00000 | Val Loss: 0.00000
#  49% 2430/5000 [28:35<29:42,  1.44it/s]INFO     [2557662568.py] Epoch 2430 | Train Loss: 0.00000 | Val Loss: 0.00000
#  49% 2440/5000 [28:42<29:54,  1.43it/s]INFO     [2557662568.py] Epoch 2440 | Train Loss: 0.00000 | Val Loss: 0.00000
#  49% 2450/5000 [28:49<30:29,  1.39it/s]INFO     [2557662568.py] Epoch 2450 | Train Loss: 0.00000 | Val Loss: 0.00001
#  49% 2460/5000 [28:56<29:28,  1.44it/s]INFO     [2557662568.py] Epoch 2460 | Train Loss: 0.00000 | Val Loss: 0.00000
#  49% 2470/5000 [29:03<29:26,  1.43it/s]INFO     [2557662568.py] Epoch 2470 | Train Loss: 0.00000 | Val Loss: 0.00006
#  50% 2480/5000 [29:10<29:15,  1.44it/s]INFO     [2557662568.py] Epoch 2480 | Train Loss: 0.00000 | Val Loss: 0.00001
#  50% 2490/5000 [29:17<29:03,  1.44it/s]INFO     [2557662568.py] Epoch 2490 | Train Loss: 0.00000 | Val Loss: 0.00000
#  50% 2500/5000 [29:24<29:23,  1.42it/s]INFO     [2557662568.py] Epoch 2500 | Train Loss: 0.00000 | Val Loss: 0.00000
#  50% 2510/5000 [29:31<29:10,  1.42it/s]INFO     [2557662568.py] Epoch 2510 | Train Loss: 0.00000 | Val Loss: 0.00000
#  50% 2520/5000 [29:38<29:21,  1.41it/s]INFO     [2557662568.py] Epoch 2520 | Train Loss: 0.00000 | Val Loss: 0.00001
#  51% 2530/5000 [29:45<28:39,  1.44it/s]INFO     [2557662568.py] Epoch 2530 | Train Loss: 0.00000 | Val Loss: 0.00001
#  51% 2540/5000 [29:53<32:42,  1.25it/s]INFO     [2557662568.py] Epoch 2540 | Train Loss: 0.00000 | Val Loss: 0.00000
#  51% 2550/5000 [30:01<32:51,  1.24it/s]INFO     [2557662568.py] Epoch 2550 | Train Loss: 0.00000 | Val Loss: 0.00000
#  51% 2560/5000 [30:09<32:32,  1.25it/s]INFO     [2557662568.py] Epoch 2560 | Train Loss: 0.00000 | Val Loss: 0.00004
#  51% 2570/5000 [30:17<29:19,  1.38it/s]INFO     [2557662568.py] Epoch 2570 | Train Loss: 0.00000 | Val Loss: 0.00001
#  52% 2580/5000 [30:24<28:01,  1.44it/s]INFO     [2557662568.py] Epoch 2580 | Train Loss: 0.00000 | Val Loss: 0.00001
#  52% 2590/5000 [30:31<28:02,  1.43it/s]INFO     [2557662568.py] Epoch 2590 | Train Loss: 0.00000 | Val Loss: 0.00000
#  52% 2600/5000 [30:38<28:10,  1.42it/s]INFO     [2557662568.py] Epoch 2600 | Train Loss: 0.00000 | Val Loss: 0.00001
#  52% 2610/5000 [30:45<27:40,  1.44it/s]INFO     [2557662568.py] Epoch 2610 | Train Loss: 0.00000 | Val Loss: 0.00001
#  52% 2620/5000 [30:52<27:44,  1.43it/s]INFO     [2557662568.py] Epoch 2620 | Train Loss: 0.00000 | Val Loss: 0.00001
#  53% 2630/5000 [30:59<27:25,  1.44it/s]INFO     [2557662568.py] Epoch 2630 | Train Loss: 0.00000 | Val Loss: 0.00002
#  53% 2640/5000 [31:05<27:24,  1.44it/s]INFO     [2557662568.py] Epoch 2640 | Train Loss: 0.00000 | Val Loss: 0.00001
#  53% 2650/5000 [31:12<27:21,  1.43it/s]INFO     [2557662568.py] Epoch 2650 | Train Loss: 0.00000 | Val Loss: 0.00000
#  53% 2660/5000 [31:19<27:21,  1.43it/s]INFO     [2557662568.py] Epoch 2660 | Train Loss: 0.00001 | Val Loss: 0.00000
#  53% 2670/5000 [31:27<31:20,  1.24it/s]INFO     [2557662568.py] Epoch 2670 | Train Loss: 0.00000 | Val Loss: 0.00000
#  54% 2680/5000 [31:35<31:21,  1.23it/s]INFO     [2557662568.py] Epoch 2680 | Train Loss: 0.00000 | Val Loss: 0.00000
#  54% 2690/5000 [31:44<31:25,  1.23it/s]INFO     [2557662568.py] Epoch 2690 | Train Loss: 0.00000 | Val Loss: 0.00000
#  54% 2700/5000 [31:51<28:00,  1.37it/s]INFO     [2557662568.py] Epoch 2700 | Train Loss: 0.00000 | Val Loss: 0.00001
#  54% 2710/5000 [31:58<27:09,  1.41it/s]INFO     [2557662568.py] Epoch 2710 | Train Loss: 0.00000 | Val Loss: 0.00000
#  54% 2720/5000 [32:05<26:41,  1.42it/s]INFO     [2557662568.py] Epoch 2720 | Train Loss: 0.00000 | Val Loss: 0.00001
#  55% 2730/5000 [32:12<26:38,  1.42it/s]INFO     [2557662568.py] Epoch 2730 | Train Loss: 0.00000 | Val Loss: 0.00000
#  55% 2740/5000 [32:19<26:24,  1.43it/s]INFO     [2557662568.py] Epoch 2740 | Train Loss: 0.00000 | Val Loss: 0.00000
#  55% 2750/5000 [32:26<26:10,  1.43it/s]INFO     [2557662568.py] Epoch 2750 | Train Loss: 0.00000 | Val Loss: 0.00004
#  55% 2760/5000 [32:34<26:13,  1.42it/s]INFO     [2557662568.py] Epoch 2760 | Train Loss: 0.00000 | Val Loss: 0.00000
#  55% 2770/5000 [32:41<26:22,  1.41it/s]INFO     [2557662568.py] Epoch 2770 | Train Loss: 0.00000 | Val Loss: 0.00000
#  56% 2780/5000 [32:48<25:55,  1.43it/s]INFO     [2557662568.py] Epoch 2780 | Train Loss: 0.00000 | Val Loss: 0.00001
#  56% 2790/5000 [32:55<25:33,  1.44it/s]INFO     [2557662568.py] Epoch 2790 | Train Loss: 0.00000 | Val Loss: 0.00000
#  56% 2800/5000 [33:02<25:38,  1.43it/s]INFO     [2557662568.py] Epoch 2800 | Train Loss: 0.00000 | Val Loss: 0.00002
#  56% 2810/5000 [33:09<28:20,  1.29it/s]INFO     [2557662568.py] Epoch 2810 | Train Loss: 0.00000 | Val Loss: 0.00000
#  56% 2820/5000 [33:17<29:27,  1.23it/s]INFO     [2557662568.py] Epoch 2820 | Train Loss: 0.00000 | Val Loss: 0.00000
#  57% 2830/5000 [33:25<29:18,  1.23it/s]INFO     [2557662568.py] Epoch 2830 | Train Loss: 0.00000 | Val Loss: 0.00000
#  57% 2840/5000 [33:33<29:06,  1.24it/s]INFO     [2557662568.py] Epoch 2840 | Train Loss: 0.00000 | Val Loss: 0.00000
#  57% 2850/5000 [33:40<25:26,  1.41it/s]INFO     [2557662568.py] Epoch 2850 | Train Loss: 0.00000 | Val Loss: 0.00000
#  57% 2860/5000 [33:47<24:58,  1.43it/s]INFO     [2557662568.py] Epoch 2860 | Train Loss: 0.00000 | Val Loss: 0.00000
#  57% 2870/5000 [33:54<25:01,  1.42it/s]INFO     [2557662568.py] Epoch 2870 | Train Loss: 0.00000 | Val Loss: 0.00000
#  58% 2880/5000 [34:01<24:43,  1.43it/s]INFO     [2557662568.py] Epoch 2880 | Train Loss: 0.00000 | Val Loss: 0.00000
#  58% 2890/5000 [34:08<24:53,  1.41it/s]INFO     [2557662568.py] Epoch 2890 | Train Loss: 0.00000 | Val Loss: 0.00000
#  58% 2900/5000 [34:16<24:43,  1.42it/s]INFO     [2557662568.py] Epoch 2900 | Train Loss: 0.00000 | Val Loss: 0.00000
#  58% 2910/5000 [34:23<24:26,  1.43it/s]INFO     [2557662568.py] Epoch 2910 | Train Loss: 0.00000 | Val Loss: 0.00001
#  58% 2920/5000 [34:30<24:17,  1.43it/s]INFO     [2557662568.py] Epoch 2920 | Train Loss: 0.00000 | Val Loss: 0.00000
#  59% 2930/5000 [34:37<24:07,  1.43it/s]INFO     [2557662568.py] Epoch 2930 | Train Loss: 0.00000 | Val Loss: 0.00001
#  59% 2940/5000 [34:44<24:02,  1.43it/s]INFO     [2557662568.py] Epoch 2940 | Train Loss: 0.00000 | Val Loss: 0.00000
#  59% 2950/5000 [34:50<23:42,  1.44it/s]INFO     [2557662568.py] Epoch 2950 | Train Loss: 0.00000 | Val Loss: 0.00001
#  59% 2960/5000 [34:57<23:46,  1.43it/s]INFO     [2557662568.py] Epoch 2960 | Train Loss: 0.00000 | Val Loss: 0.00001
#  59% 2970/5000 [35:04<23:40,  1.43it/s]INFO     [2557662568.py] Epoch 2970 | Train Loss: 0.00000 | Val Loss: 0.00000
#  60% 2980/5000 [35:11<23:25,  1.44it/s]INFO     [2557662568.py] Epoch 2980 | Train Loss: 0.00000 | Val Loss: 0.00001
#  60% 2990/5000 [35:18<23:32,  1.42it/s]INFO     [2557662568.py] Epoch 2990 | Train Loss: 0.00000 | Val Loss: 0.00000
#  60% 3000/5000 [35:26<26:41,  1.25it/s]INFO     [2557662568.py] Epoch 3000 | Train Loss: 0.00000 | Val Loss: 0.00002
#  60% 3010/5000 [35:35<26:46,  1.24it/s]INFO     [2557662568.py] Epoch 3010 | Train Loss: 0.00000 | Val Loss: 0.00000
#  60% 3020/5000 [35:43<26:51,  1.23it/s]INFO     [2557662568.py] Epoch 3020 | Train Loss: 0.00000 | Val Loss: 0.00000
#  61% 3030/5000 [35:50<23:04,  1.42it/s]INFO     [2557662568.py] Epoch 3030 | Train Loss: 0.00000 | Val Loss: 0.00001
#  61% 3040/5000 [35:57<23:01,  1.42it/s]INFO     [2557662568.py] Epoch 3040 | Train Loss: 0.00000 | Val Loss: 0.00000
#  61% 3050/5000 [36:04<22:43,  1.43it/s]INFO     [2557662568.py] Epoch 3050 | Train Loss: 0.00000 | Val Loss: 0.00000
#  61% 3060/5000 [36:11<22:56,  1.41it/s]INFO     [2557662568.py] Epoch 3060 | Train Loss: 0.00000 | Val Loss: 0.00000
#  61% 3070/5000 [36:18<22:34,  1.42it/s]INFO     [2557662568.py] Epoch 3070 | Train Loss: 0.00000 | Val Loss: 0.00001
#  62% 3080/5000 [36:25<22:48,  1.40it/s]INFO     [2557662568.py] Epoch 3080 | Train Loss: 0.00000 | Val Loss: 0.00001
#  62% 3090/5000 [36:32<22:14,  1.43it/s]INFO     [2557662568.py] Epoch 3090 | Train Loss: 0.00000 | Val Loss: 0.00001
#  62% 3100/5000 [36:39<22:31,  1.41it/s]INFO     [2557662568.py] Epoch 3100 | Train Loss: 0.00000 | Val Loss: 0.00000
#  62% 3110/5000 [36:46<22:14,  1.42it/s]INFO     [2557662568.py] Epoch 3110 | Train Loss: 0.00000 | Val Loss: 0.00000
#  62% 3120/5000 [36:53<22:07,  1.42it/s]INFO     [2557662568.py] Epoch 3120 | Train Loss: 0.00000 | Val Loss: 0.00000
#  63% 3130/5000 [37:00<22:02,  1.41it/s]INFO     [2557662568.py] Epoch 3130 | Train Loss: 0.00000 | Val Loss: 0.00001
#  63% 3140/5000 [37:07<21:44,  1.43it/s]INFO     [2557662568.py] Epoch 3140 | Train Loss: 0.00000 | Val Loss: 0.00000
#  63% 3150/5000 [37:14<19:03,  1.62it/s]INFO     [2557662568.py] Epoch 3150 | Train Loss: 0.00000 | Val Loss: 0.00000
#  63% 3160/5000 [37:21<21:34,  1.42it/s]INFO     [2557662568.py] Epoch 3160 | Train Loss: 0.00000 | Val Loss: 0.00001
#  63% 3170/5000 [37:28<21:13,  1.44it/s]INFO     [2557662568.py] Epoch 3170 | Train Loss: 0.00000 | Val Loss: 0.00000
#  64% 3180/5000 [37:35<21:21,  1.42it/s]INFO     [2557662568.py] Epoch 3180 | Train Loss: 0.00000 | Val Loss: 0.00000
#  64% 3190/5000 [37:42<21:14,  1.42it/s]INFO     [2557662568.py] Epoch 3190 | Train Loss: 0.00000 | Val Loss: 0.00002
#  64% 3200/5000 [37:49<21:04,  1.42it/s]INFO     [2557662568.py] Epoch 3200 | Train Loss: 0.00000 | Val Loss: 0.00000
#  64% 3210/5000 [37:56<19:06,  1.56it/s]INFO     [2557662568.py] Epoch 3210 | Train Loss: 0.00000 | Val Loss: 0.00001
#  64% 3220/5000 [38:02<18:18,  1.62it/s]INFO     [2557662568.py] Epoch 3220 | Train Loss: 0.00000 | Val Loss: 0.00000
#  65% 3230/5000 [38:08<18:10,  1.62it/s]INFO     [2557662568.py] Epoch 3230 | Train Loss: 0.00000 | Val Loss: 0.00000
#  65% 3240/5000 [38:14<18:03,  1.62it/s]INFO     [2557662568.py] Epoch 3240 | Train Loss: 0.00000 | Val Loss: 0.00000
#  65% 3250/5000 [38:20<18:36,  1.57it/s]INFO     [2557662568.py] Epoch 3250 | Train Loss: 0.00000 | Val Loss: 0.00000
#  65% 3260/5000 [38:27<20:23,  1.42it/s]INFO     [2557662568.py] Epoch 3260 | Train Loss: 0.00000 | Val Loss: 0.00000
#  65% 3270/5000 [38:35<20:18,  1.42it/s]INFO     [2557662568.py] Epoch 3270 | Train Loss: 0.00000 | Val Loss: 0.00000
#  66% 3280/5000 [38:42<19:59,  1.43it/s]INFO     [2557662568.py] Epoch 3280 | Train Loss: 0.00000 | Val Loss: 0.00000
#  66% 3290/5000 [38:49<20:14,  1.41it/s]INFO     [2557662568.py] Epoch 3290 | Train Loss: 0.00000 | Val Loss: 0.00000
#  66% 3300/5000 [38:56<19:48,  1.43it/s]INFO     [2557662568.py] Epoch 3300 | Train Loss: 0.00000 | Val Loss: 0.00000
#  66% 3310/5000 [39:03<19:43,  1.43it/s]INFO     [2557662568.py] Epoch 3310 | Train Loss: 0.00000 | Val Loss: 0.00000
#  66% 3320/5000 [39:10<19:42,  1.42it/s]INFO     [2557662568.py] Epoch 3320 | Train Loss: 0.00000 | Val Loss: 0.00002
#  67% 3330/5000 [39:17<19:40,  1.41it/s]INFO     [2557662568.py] Epoch 3330 | Train Loss: 0.00000 | Val Loss: 0.00000
#  67% 3340/5000 [39:24<19:30,  1.42it/s]INFO     [2557662568.py] Epoch 3340 | Train Loss: 0.00000 | Val Loss: 0.00001
#  67% 3350/5000 [39:31<19:23,  1.42it/s]INFO     [2557662568.py] Epoch 3350 | Train Loss: 0.00000 | Val Loss: 0.00000
#  67% 3360/5000 [39:38<19:09,  1.43it/s]INFO     [2557662568.py] Epoch 3360 | Train Loss: 0.00000 | Val Loss: 0.00001
#  67% 3370/5000 [39:45<18:59,  1.43it/s]INFO     [2557662568.py] Epoch 3370 | Train Loss: 0.00000 | Val Loss: 0.00000
#  68% 3380/5000 [39:52<19:04,  1.42it/s]INFO     [2557662568.py] Epoch 3380 | Train Loss: 0.00000 | Val Loss: 0.00000
#  68% 3390/5000 [39:59<17:10,  1.56it/s]INFO     [2557662568.py] Epoch 3390 | Train Loss: 0.00000 | Val Loss: 0.00000
#  68% 3400/5000 [40:05<16:25,  1.62it/s]INFO     [2557662568.py] Epoch 3400 | Train Loss: 0.00000 | Val Loss: 0.00000
#  68% 3410/5000 [40:11<16:17,  1.63it/s]INFO     [2557662568.py] Epoch 3410 | Train Loss: 0.00000 | Val Loss: 0.00000
#  68% 3420/5000 [40:17<16:11,  1.63it/s]INFO     [2557662568.py] Epoch 3420 | Train Loss: 0.00000 | Val Loss: 0.00000
#  69% 3430/5000 [40:23<16:05,  1.63it/s]INFO     [2557662568.py] Epoch 3430 | Train Loss: 0.00000 | Val Loss: 0.00000
#  69% 3440/5000 [40:29<15:59,  1.63it/s]INFO     [2557662568.py] Epoch 3440 | Train Loss: 0.00000 | Val Loss: 0.00000
#  69% 3450/5000 [40:36<15:53,  1.63it/s]INFO     [2557662568.py] Epoch 3450 | Train Loss: 0.00000 | Val Loss: 0.00000
#  69% 3460/5000 [40:42<15:46,  1.63it/s]INFO     [2557662568.py] Epoch 3460 | Train Loss: 0.00000 | Val Loss: 0.00000
#  69% 3470/5000 [40:48<15:41,  1.63it/s]INFO     [2557662568.py] Epoch 3470 | Train Loss: 0.00000 | Val Loss: 0.00000
#  70% 3480/5000 [40:54<15:34,  1.63it/s]INFO     [2557662568.py] Epoch 3480 | Train Loss: 0.00000 | Val Loss: 0.00000
#  70% 3490/5000 [41:00<16:47,  1.50it/s]INFO     [2557662568.py] Epoch 3490 | Train Loss: 0.00000 | Val Loss: 0.00000
#  70% 3500/5000 [41:07<17:17,  1.45it/s]INFO     [2557662568.py] Epoch 3500 | Train Loss: 0.00000 | Val Loss: 0.00000
#  70% 3510/5000 [41:14<17:13,  1.44it/s]INFO     [2557662568.py] Epoch 3510 | Train Loss: 0.00000 | Val Loss: 0.00000
#  70% 3520/5000 [41:21<17:14,  1.43it/s]INFO     [2557662568.py] Epoch 3520 | Train Loss: 0.00000 | Val Loss: 0.00000
#  71% 3530/5000 [41:28<17:13,  1.42it/s]INFO     [2557662568.py] Epoch 3530 | Train Loss: 0.00000 | Val Loss: 0.00000
#  71% 3540/5000 [41:35<17:05,  1.42it/s]INFO     [2557662568.py] Epoch 3540 | Train Loss: 0.00000 | Val Loss: 0.00000
#  71% 3550/5000 [41:42<16:54,  1.43it/s]INFO     [2557662568.py] Epoch 3550 | Train Loss: 0.00000 | Val Loss: 0.00000
#  71% 3560/5000 [41:49<16:41,  1.44it/s]INFO     [2557662568.py] Epoch 3560 | Train Loss: 0.00000 | Val Loss: 0.00000
#  71% 3570/5000 [41:56<16:43,  1.43it/s]INFO     [2557662568.py] Epoch 3570 | Train Loss: 0.00000 | Val Loss: 0.00001
#  72% 3580/5000 [42:03<14:47,  1.60it/s]INFO     [2557662568.py] Epoch 3580 | Train Loss: 0.00000 | Val Loss: 0.00000
#  72% 3590/5000 [42:09<14:15,  1.65it/s]INFO     [2557662568.py] Epoch 3590 | Train Loss: 0.00000 | Val Loss: 0.00000
#  72% 3600/5000 [42:15<15:31,  1.50it/s]INFO     [2557662568.py] Epoch 3600 | Train Loss: 0.00000 | Val Loss: 0.00000
#  72% 3610/5000 [42:22<16:06,  1.44it/s]INFO     [2557662568.py] Epoch 3610 | Train Loss: 0.00000 | Val Loss: 0.00000
#  72% 3620/5000 [42:29<16:04,  1.43it/s]INFO     [2557662568.py] Epoch 3620 | Train Loss: 0.00000 | Val Loss: 0.00000
#  73% 3630/5000 [42:36<16:01,  1.42it/s]INFO     [2557662568.py] Epoch 3630 | Train Loss: 0.00000 | Val Loss: 0.00000
#  73% 3640/5000 [42:43<15:46,  1.44it/s]INFO     [2557662568.py] Epoch 3640 | Train Loss: 0.00000 | Val Loss: 0.00000
#  73% 3650/5000 [42:50<15:40,  1.44it/s]INFO     [2557662568.py] Epoch 3650 | Train Loss: 0.00000 | Val Loss: 0.00000
#  73% 3660/5000 [42:57<15:33,  1.44it/s]INFO     [2557662568.py] Epoch 3660 | Train Loss: 0.00000 | Val Loss: 0.00000
#  73% 3670/5000 [43:04<15:33,  1.43it/s]INFO     [2557662568.py] Epoch 3670 | Train Loss: 0.00000 | Val Loss: 0.00000
#  74% 3680/5000 [43:11<15:29,  1.42it/s]INFO     [2557662568.py] Epoch 3680 | Train Loss: 0.00000 | Val Loss: 0.00000
#  74% 3690/5000 [43:18<15:18,  1.43it/s]INFO     [2557662568.py] Epoch 3690 | Train Loss: 0.00000 | Val Loss: 0.00000
#  74% 3700/5000 [43:25<15:11,  1.43it/s]INFO     [2557662568.py] Epoch 3700 | Train Loss: 0.00000 | Val Loss: 0.00000
#  74% 3710/5000 [43:32<15:05,  1.42it/s]INFO     [2557662568.py] Epoch 3710 | Train Loss: 0.00000 | Val Loss: 0.00000
#  74% 3720/5000 [43:39<14:55,  1.43it/s]INFO     [2557662568.py] Epoch 3720 | Train Loss: 0.00000 | Val Loss: 0.00000
#  75% 3730/5000 [43:46<14:54,  1.42it/s]INFO     [2557662568.py] Epoch 3730 | Train Loss: 0.00000 | Val Loss: 0.00000
#  75% 3740/5000 [43:53<14:44,  1.42it/s]INFO     [2557662568.py] Epoch 3740 | Train Loss: 0.00000 | Val Loss: 0.00000
#  75% 3750/5000 [44:00<14:34,  1.43it/s]INFO     [2557662568.py] Epoch 3750 | Train Loss: 0.00000 | Val Loss: 0.00000
#  75% 3760/5000 [44:07<14:23,  1.44it/s]INFO     [2557662568.py] Epoch 3760 | Train Loss: 0.00000 | Val Loss: 0.00000
#  75% 3770/5000 [44:14<14:26,  1.42it/s]INFO     [2557662568.py] Epoch 3770 | Train Loss: 0.00000 | Val Loss: 0.00000
#  76% 3780/5000 [44:21<14:11,  1.43it/s]INFO     [2557662568.py] Epoch 3780 | Train Loss: 0.00000 | Val Loss: 0.00000
#  76% 3790/5000 [44:28<14:02,  1.44it/s]INFO     [2557662568.py] Epoch 3790 | Train Loss: 0.00000 | Val Loss: 0.00000
#  76% 3800/5000 [44:35<13:56,  1.43it/s]INFO     [2557662568.py] Epoch 3800 | Train Loss: 0.00000 | Val Loss: 0.00000
#  76% 3810/5000 [44:42<13:45,  1.44it/s]INFO     [2557662568.py] Epoch 3810 | Train Loss: 0.00000 | Val Loss: 0.00000
#  76% 3820/5000 [44:49<13:39,  1.44it/s]INFO     [2557662568.py] Epoch 3820 | Train Loss: 0.00000 | Val Loss: 0.00000
#  77% 3830/5000 [44:56<13:36,  1.43it/s]INFO     [2557662568.py] Epoch 3830 | Train Loss: 0.00000 | Val Loss: 0.00000
#  77% 3840/5000 [45:03<13:30,  1.43it/s]INFO     [2557662568.py] Epoch 3840 | Train Loss: 0.00000 | Val Loss: 0.00000
#  77% 3850/5000 [45:10<13:21,  1.43it/s]INFO     [2557662568.py] Epoch 3850 | Train Loss: 0.00000 | Val Loss: 0.00000
#  77% 3860/5000 [45:17<13:18,  1.43it/s]INFO     [2557662568.py] Epoch 3860 | Train Loss: 0.00000 | Val Loss: 0.00000
#  77% 3870/5000 [45:24<13:14,  1.42it/s]INFO     [2557662568.py] Epoch 3870 | Train Loss: 0.00000 | Val Loss: 0.00000
#  78% 3880/5000 [45:31<13:03,  1.43it/s]INFO     [2557662568.py] Epoch 3880 | Train Loss: 0.00000 | Val Loss: 0.00000
#  78% 3890/5000 [45:38<12:55,  1.43it/s]INFO     [2557662568.py] Epoch 3890 | Train Loss: 0.00000 | Val Loss: 0.00000
#  78% 3900/5000 [45:45<12:43,  1.44it/s]INFO     [2557662568.py] Epoch 3900 | Train Loss: 0.00000 | Val Loss: 0.00000
#  78% 3910/5000 [45:52<12:46,  1.42it/s]INFO     [2557662568.py] Epoch 3910 | Train Loss: 0.00000 | Val Loss: 0.00000
#  78% 3920/5000 [45:59<12:38,  1.42it/s]INFO     [2557662568.py] Epoch 3920 | Train Loss: 0.00000 | Val Loss: 0.00000
#  79% 3930/5000 [46:06<12:28,  1.43it/s]INFO     [2557662568.py] Epoch 3930 | Train Loss: 0.00000 | Val Loss: 0.00000
#  79% 3940/5000 [46:13<12:24,  1.42it/s]INFO     [2557662568.py] Epoch 3940 | Train Loss: 0.00000 | Val Loss: 0.00000
#  79% 3950/5000 [46:20<12:14,  1.43it/s]INFO     [2557662568.py] Epoch 3950 | Train Loss: 0.00000 | Val Loss: 0.00000
#  79% 3960/5000 [46:27<12:18,  1.41it/s]INFO     [2557662568.py] Epoch 3960 | Train Loss: 0.00000 | Val Loss: 0.00000
#  79% 3970/5000 [46:34<12:03,  1.42it/s]INFO     [2557662568.py] Epoch 3970 | Train Loss: 0.00000 | Val Loss: 0.00000
#  80% 3980/5000 [46:42<12:02,  1.41it/s]INFO     [2557662568.py] Epoch 3980 | Train Loss: 0.00000 | Val Loss: 0.00000
#  80% 3990/5000 [46:49<11:48,  1.43it/s]INFO     [2557662568.py] Epoch 3990 | Train Loss: 0.00000 | Val Loss: 0.00000
#  80% 4000/5000 [46:55<11:40,  1.43it/s]INFO     [2557662568.py] Epoch 4000 | Train Loss: 0.00000 | Val Loss: 0.00000
#  80% 4010/5000 [47:03<11:36,  1.42it/s]INFO     [2557662568.py] Epoch 4010 | Train Loss: 0.00000 | Val Loss: 0.00000
#  80% 4020/5000 [47:10<11:26,  1.43it/s]INFO     [2557662568.py] Epoch 4020 | Train Loss: 0.00000 | Val Loss: 0.00000
#  81% 4030/5000 [47:17<11:23,  1.42it/s]INFO     [2557662568.py] Epoch 4030 | Train Loss: 0.00000 | Val Loss: 0.00000
#  81% 4040/5000 [47:24<11:17,  1.42it/s]INFO     [2557662568.py] Epoch 4040 | Train Loss: 0.00000 | Val Loss: 0.00000
#  81% 4050/5000 [47:31<11:09,  1.42it/s]INFO     [2557662568.py] Epoch 4050 | Train Loss: 0.00000 | Val Loss: 0.00000
#  81% 4060/5000 [47:38<11:03,  1.42it/s]INFO     [2557662568.py] Epoch 4060 | Train Loss: 0.00000 | Val Loss: 0.00000
#  81% 4070/5000 [47:45<11:11,  1.39it/s]INFO     [2557662568.py] Epoch 4070 | Train Loss: 0.00000 | Val Loss: 0.00000
#  82% 4080/5000 [47:52<10:44,  1.43it/s]INFO     [2557662568.py] Epoch 4080 | Train Loss: 0.00000 | Val Loss: 0.00000
#  82% 4090/5000 [47:59<10:44,  1.41it/s]INFO     [2557662568.py] Epoch 4090 | Train Loss: 0.00000 | Val Loss: 0.00000
#  82% 4100/5000 [48:06<10:33,  1.42it/s]INFO     [2557662568.py] Epoch 4100 | Train Loss: 0.00000 | Val Loss: 0.00000
#  82% 4110/5000 [48:13<10:29,  1.41it/s]INFO     [2557662568.py] Epoch 4110 | Train Loss: 0.00000 | Val Loss: 0.00000
#  82% 4120/5000 [48:20<10:17,  1.42it/s]INFO     [2557662568.py] Epoch 4120 | Train Loss: 0.00000 | Val Loss: 0.00000
#  83% 4130/5000 [48:27<10:10,  1.42it/s]INFO     [2557662568.py] Epoch 4130 | Train Loss: 0.00000 | Val Loss: 0.00000
#  83% 4140/5000 [48:34<10:12,  1.40it/s]INFO     [2557662568.py] Epoch 4140 | Train Loss: 0.00000 | Val Loss: 0.00000
#  83% 4150/5000 [48:41<09:55,  1.43it/s]INFO     [2557662568.py] Epoch 4150 | Train Loss: 0.00000 | Val Loss: 0.00000
#  83% 4160/5000 [48:48<09:48,  1.43it/s]INFO     [2557662568.py] Epoch 4160 | Train Loss: 0.00000 | Val Loss: 0.00000
#  83% 4170/5000 [48:55<09:43,  1.42it/s]INFO     [2557662568.py] Epoch 4170 | Train Loss: 0.00000 | Val Loss: 0.00000
#  84% 4180/5000 [49:02<09:35,  1.43it/s]INFO     [2557662568.py] Epoch 4180 | Train Loss: 0.00000 | Val Loss: 0.00000
#  84% 4190/5000 [49:09<09:33,  1.41it/s]INFO     [2557662568.py] Epoch 4190 | Train Loss: 0.00000 | Val Loss: 0.00000
#  84% 4200/5000 [49:16<09:24,  1.42it/s]INFO     [2557662568.py] Epoch 4200 | Train Loss: 0.00000 | Val Loss: 0.00000
#  84% 4210/5000 [49:24<09:16,  1.42it/s]INFO     [2557662568.py] Epoch 4210 | Train Loss: 0.00000 | Val Loss: 0.00000
#  84% 4220/5000 [49:31<09:06,  1.43it/s]INFO     [2557662568.py] Epoch 4220 | Train Loss: 0.00000 | Val Loss: 0.00000
#  85% 4230/5000 [49:38<09:07,  1.41it/s]INFO     [2557662568.py] Epoch 4230 | Train Loss: 0.00000 | Val Loss: 0.00000
#  85% 4240/5000 [49:45<08:52,  1.43it/s]INFO     [2557662568.py] Epoch 4240 | Train Loss: 0.00000 | Val Loss: 0.00000
#  85% 4250/5000 [49:52<08:49,  1.42it/s]INFO     [2557662568.py] Epoch 4250 | Train Loss: 0.00000 | Val Loss: 0.00000
#  85% 4260/5000 [49:59<08:39,  1.43it/s]INFO     [2557662568.py] Epoch 4260 | Train Loss: 0.00000 | Val Loss: 0.00000
#  85% 4270/5000 [50:06<08:39,  1.40it/s]INFO     [2557662568.py] Epoch 4270 | Train Loss: 0.00000 | Val Loss: 0.00000
#  86% 4280/5000 [50:13<08:30,  1.41it/s]INFO     [2557662568.py] Epoch 4280 | Train Loss: 0.00000 | Val Loss: 0.00000
#  86% 4290/5000 [50:20<08:20,  1.42it/s]INFO     [2557662568.py] Epoch 4290 | Train Loss: 0.00000 | Val Loss: 0.00000
#  86% 4300/5000 [50:27<08:14,  1.42it/s]INFO     [2557662568.py] Epoch 4300 | Train Loss: 0.00000 | Val Loss: 0.00000
#  86% 4310/5000 [50:34<08:06,  1.42it/s]INFO     [2557662568.py] Epoch 4310 | Train Loss: 0.00000 | Val Loss: 0.00000
#  86% 4320/5000 [50:41<07:57,  1.42it/s]INFO     [2557662568.py] Epoch 4320 | Train Loss: 0.00000 | Val Loss: 0.00000
#  87% 4330/5000 [50:48<07:53,  1.42it/s]INFO     [2557662568.py] Epoch 4330 | Train Loss: 0.00000 | Val Loss: 0.00000
#  87% 4340/5000 [50:55<07:45,  1.42it/s]INFO     [2557662568.py] Epoch 4340 | Train Loss: 0.00000 | Val Loss: 0.00000
#  87% 4350/5000 [51:02<06:58,  1.55it/s]INFO     [2557662568.py] Epoch 4350 | Train Loss: 0.00000 | Val Loss: 0.00000
#  87% 4360/5000 [51:08<06:34,  1.62it/s]INFO     [2557662568.py] Epoch 4360 | Train Loss: 0.00000 | Val Loss: 0.00000
#  87% 4370/5000 [51:14<06:27,  1.62it/s]INFO     [2557662568.py] Epoch 4370 | Train Loss: 0.00000 | Val Loss: 0.00000
#  88% 4380/5000 [51:21<06:21,  1.62it/s]INFO     [2557662568.py] Epoch 4380 | Train Loss: 0.00000 | Val Loss: 0.00000
#  88% 4390/5000 [51:27<06:15,  1.62it/s]INFO     [2557662568.py] Epoch 4390 | Train Loss: 0.00000 | Val Loss: 0.00000
#  88% 4400/5000 [51:33<06:09,  1.62it/s]INFO     [2557662568.py] Epoch 4400 | Train Loss: 0.00000 | Val Loss: 0.00000
#  88% 4410/5000 [51:39<06:03,  1.63it/s]INFO     [2557662568.py] Epoch 4410 | Train Loss: 0.00000 | Val Loss: 0.00000
#  88% 4420/5000 [51:45<05:57,  1.62it/s]INFO     [2557662568.py] Epoch 4420 | Train Loss: 0.00000 | Val Loss: 0.00000
#  89% 4430/5000 [51:51<05:51,  1.62it/s]INFO     [2557662568.py] Epoch 4430 | Train Loss: 0.00000 | Val Loss: 0.00000
#  89% 4440/5000 [51:57<05:44,  1.62it/s]INFO     [2557662568.py] Epoch 4440 | Train Loss: 0.00000 | Val Loss: 0.00000
#  89% 4450/5000 [52:04<05:38,  1.62it/s]INFO     [2557662568.py] Epoch 4450 | Train Loss: 0.00000 | Val Loss: 0.00000
#  89% 4460/5000 [52:10<05:32,  1.62it/s]INFO     [2557662568.py] Epoch 4460 | Train Loss: 0.00000 | Val Loss: 0.00000
#  89% 4470/5000 [52:16<05:24,  1.63it/s]INFO     [2557662568.py] Epoch 4470 | Train Loss: 0.00000 | Val Loss: 0.00000
#  90% 4480/5000 [52:23<06:00,  1.44it/s]INFO     [2557662568.py] Epoch 4480 | Train Loss: 0.00000 | Val Loss: 0.00000
#  90% 4490/5000 [52:30<05:59,  1.42it/s]INFO     [2557662568.py] Epoch 4490 | Train Loss: 0.00000 | Val Loss: 0.00000
#  90% 4500/5000 [52:37<05:51,  1.42it/s]INFO     [2557662568.py] Epoch 4500 | Train Loss: 0.00000 | Val Loss: 0.00000
#  90% 4510/5000 [52:44<05:13,  1.56it/s]INFO     [2557662568.py] Epoch 4510 | Train Loss: 0.00000 | Val Loss: 0.00000
#  90% 4520/5000 [52:50<04:57,  1.61it/s]INFO     [2557662568.py] Epoch 4520 | Train Loss: 0.00000 | Val Loss: 0.00000
#  91% 4530/5000 [52:56<04:51,  1.61it/s]INFO     [2557662568.py] Epoch 4530 | Train Loss: 0.00000 | Val Loss: 0.00000
#  91% 4540/5000 [53:03<05:19,  1.44it/s]INFO     [2557662568.py] Epoch 4540 | Train Loss: 0.00000 | Val Loss: 0.00000
#  91% 4550/5000 [53:10<05:21,  1.40it/s]INFO     [2557662568.py] Epoch 4550 | Train Loss: 0.00000 | Val Loss: 0.00000
#  91% 4560/5000 [53:17<04:57,  1.48it/s]INFO     [2557662568.py] Epoch 4560 | Train Loss: 0.00000 | Val Loss: 0.00000
#  91% 4570/5000 [53:23<04:25,  1.62it/s]INFO     [2557662568.py] Epoch 4570 | Train Loss: 0.00000 | Val Loss: 0.00000
#  92% 4580/5000 [53:29<04:18,  1.63it/s]INFO     [2557662568.py] Epoch 4580 | Train Loss: 0.00000 | Val Loss: 0.00000
#  92% 4590/5000 [53:35<04:09,  1.64it/s]INFO     [2557662568.py] Epoch 4590 | Train Loss: 0.00000 | Val Loss: 0.00000
#  92% 4600/5000 [53:42<04:31,  1.47it/s]INFO     [2557662568.py] Epoch 4600 | Train Loss: 0.00000 | Val Loss: 0.00000
#  92% 4610/5000 [53:49<04:30,  1.44it/s]INFO     [2557662568.py] Epoch 4610 | Train Loss: 0.00000 | Val Loss: 0.00000
#  92% 4620/5000 [53:56<04:25,  1.43it/s]INFO     [2557662568.py] Epoch 4620 | Train Loss: 0.00000 | Val Loss: 0.00000
#  93% 4630/5000 [54:03<04:18,  1.43it/s]INFO     [2557662568.py] Epoch 4630 | Train Loss: 0.00000 | Val Loss: 0.00000
#  93% 4640/5000 [54:10<04:09,  1.44it/s]INFO     [2557662568.py] Epoch 4640 | Train Loss: 0.00000 | Val Loss: 0.00000
#  93% 4650/5000 [54:17<04:05,  1.42it/s]INFO     [2557662568.py] Epoch 4650 | Train Loss: 0.00000 | Val Loss: 0.00000
#  93% 4660/5000 [54:24<03:59,  1.42it/s]INFO     [2557662568.py] Epoch 4660 | Train Loss: 0.00000 | Val Loss: 0.00000
#  93% 4670/5000 [54:31<03:51,  1.43it/s]INFO     [2557662568.py] Epoch 4670 | Train Loss: 0.00000 | Val Loss: 0.00000
#  94% 4680/5000 [54:37<03:18,  1.61it/s]INFO     [2557662568.py] Epoch 4680 | Train Loss: 0.00000 | Val Loss: 0.00000
#  94% 4690/5000 [54:43<03:11,  1.62it/s]INFO     [2557662568.py] Epoch 4690 | Train Loss: 0.00000 | Val Loss: 0.00000
#  94% 4700/5000 [54:50<03:05,  1.62it/s]INFO     [2557662568.py] Epoch 4700 | Train Loss: 0.00000 | Val Loss: 0.00000
#  94% 4710/5000 [54:56<02:59,  1.62it/s]INFO     [2557662568.py] Epoch 4710 | Train Loss: 0.00000 | Val Loss: 0.00000
#  94% 4720/5000 [55:02<02:53,  1.62it/s]INFO     [2557662568.py] Epoch 4720 | Train Loss: 0.00000 | Val Loss: 0.00000
#  95% 4730/5000 [55:08<02:47,  1.62it/s]INFO     [2557662568.py] Epoch 4730 | Train Loss: 0.00000 | Val Loss: 0.00000
#  95% 4740/5000 [55:14<02:40,  1.62it/s]INFO     [2557662568.py] Epoch 4740 | Train Loss: 0.00000 | Val Loss: 0.00000
#  95% 4750/5000 [55:21<02:34,  1.62it/s]INFO     [2557662568.py] Epoch 4750 | Train Loss: 0.00000 | Val Loss: 0.00000
#  95% 4760/5000 [55:27<02:28,  1.62it/s]INFO     [2557662568.py] Epoch 4760 | Train Loss: 0.00000 | Val Loss: 0.00000
#  95% 4770/5000 [55:33<02:22,  1.62it/s]INFO     [2557662568.py] Epoch 4770 | Train Loss: 0.00000 | Val Loss: 0.00000
#  96% 4780/5000 [55:39<02:16,  1.62it/s]INFO     [2557662568.py] Epoch 4780 | Train Loss: 0.00000 | Val Loss: 0.00000
#  96% 4790/5000 [55:45<02:09,  1.62it/s]INFO     [2557662568.py] Epoch 4790 | Train Loss: 0.00000 | Val Loss: 0.00000
#  96% 4800/5000 [55:51<02:03,  1.62it/s]INFO     [2557662568.py] Epoch 4800 | Train Loss: 0.00000 | Val Loss: 0.00000
#  96% 4810/5000 [55:58<01:57,  1.62it/s]INFO     [2557662568.py] Epoch 4810 | Train Loss: 0.00000 | Val Loss: 0.00000
#  96% 4820/5000 [56:04<01:51,  1.62it/s]INFO     [2557662568.py] Epoch 4820 | Train Loss: 0.00000 | Val Loss: 0.00000
#  97% 4830/5000 [56:10<01:45,  1.62it/s]INFO     [2557662568.py] Epoch 4830 | Train Loss: 0.00000 | Val Loss: 0.00000
#  97% 4840/5000 [56:16<01:38,  1.62it/s]INFO     [2557662568.py] Epoch 4840 | Train Loss: 0.00000 | Val Loss: 0.00000
#  97% 4850/5000 [56:22<01:32,  1.62it/s]INFO     [2557662568.py] Epoch 4850 | Train Loss: 0.00000 | Val Loss: 0.00000
#  97% 4860/5000 [56:29<01:26,  1.62it/s]INFO     [2557662568.py] Epoch 4860 | Train Loss: 0.00000 | Val Loss: 0.00000
#  97% 4870/5000 [56:35<01:20,  1.62it/s]INFO     [2557662568.py] Epoch 4870 | Train Loss: 0.00000 | Val Loss: 0.00000
#  98% 4880/5000 [56:41<01:14,  1.62it/s]INFO     [2557662568.py] Epoch 4880 | Train Loss: 0.00000 | Val Loss: 0.00000
#  98% 4890/5000 [56:47<01:08,  1.62it/s]INFO     [2557662568.py] Epoch 4890 | Train Loss: 0.00000 | Val Loss: 0.00000
#  98% 4900/5000 [56:53<01:01,  1.62it/s]INFO     [2557662568.py] Epoch 4900 | Train Loss: 0.00000 | Val Loss: 0.00000
#  98% 4910/5000 [57:00<01:01,  1.46it/s]INFO     [2557662568.py] Epoch 4910 | Train Loss: 0.00000 | Val Loss: 0.00000
#  98% 4920/5000 [57:07<00:51,  1.56it/s]INFO     [2557662568.py] Epoch 4920 | Train Loss: 0.00000 | Val Loss: 0.00000
#  99% 4930/5000 [57:14<00:50,  1.39it/s]INFO     [2557662568.py] Epoch 4930 | Train Loss: 0.00000 | Val Loss: 0.00000
#  99% 4940/5000 [57:21<00:41,  1.43it/s]INFO     [2557662568.py] Epoch 4940 | Train Loss: 0.00000 | Val Loss: 0.00000
#  99% 4950/5000 [57:28<00:34,  1.43it/s]INFO     [2557662568.py] Epoch 4950 | Train Loss: 0.00000 | Val Loss: 0.00000
#  99% 4960/5000 [57:35<00:28,  1.42it/s]INFO     [2557662568.py] Epoch 4960 | Train Loss: 0.00000 | Val Loss: 0.00000
#  99% 4970/5000 [57:42<00:20,  1.43it/s]INFO     [2557662568.py] Epoch 4970 | Train Loss: 0.00000 | Val Loss: 0.00000
# 100% 4980/5000 [57:49<00:14,  1.41it/s]INFO     [2557662568.py] Epoch 4980 | Train Loss: 0.00000 | Val Loss: 0.00000
# 100% 4990/5000 [57:56<00:06,  1.44it/s]INFO     [2557662568.py] Epoch 4990 | Train Loss: 0.00000 | Val Loss: 0.00000
# 100% 5000/5000 [58:03<00:00,  1.44it/s]
# INFO     [2557662568.py] model has been saved in:save_models/sp500_20082017_corr_ser_reg_corr_mat_hrchy_11_cluster-train_train/corr_s1_w50
# time: 58min 4s (started: 2023-02-18 16:26:26 +00:00)
